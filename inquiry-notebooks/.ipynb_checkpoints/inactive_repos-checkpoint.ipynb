# %%
import psycopg2
import pandas as pd 
# from sqlalchemy.types import Integer, Text, String, DateTime
import sqlalchemy as s
import matplotlib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

with open("config.json") as config_file:
    config = json.load(config_file)

database_connection_string = 'postgres+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = s.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %%
    # Create a dictionary that maps email addresses to github ids
    id_dict = {}
    id_df = pd.DataFrame()
    id_df_query = f"""
            SELECT cntrb_email, cntrb_login from contributors
            """
    id_df = pd.read_sql_query(id_df_query, con=engine)
    id_dict = id_df.set_index('cntrb_email').T.to_dict('list')
#    id_dict = id_df.set_index('cntrb_email').T.to_dict('dict')
    id_df
# Out:
# <ipython-input-2-5da67eba5a49>:8: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   id_dict = id_df.set_index('cntrb_email').T.to_dict('list')
#                      cntrb_email    cntrb_login
# 0                           None   not-provided
# 1                           None          ctk3b
# 2                           None  mattwthompson
# 3            crs@oslic5.llnl.gov           None
# 4              ayang41@gmail.com         ahy3nz
# ...                          ...            ...
# 9958         gery.ogam@gmail.com       maggyero
# 9959  victor.zverovich@gmail.com         vitaut
# 9960                        None          dfrib
# 9961      aaronjjacobs@gmail.com        jacobsa
# 9962          g.louppe@gmail.com        glouppe
#
# [9963 rows x 2 columns]

# %%
#print(id_dict['s@goggins.com'][0])

# %%
all_commits = pd.DataFrame()
all_commits_query = f"""
        SELECT DISTINCT(commits.cmt_commit_hash), repo.repo_id, repo.repo_name, repo.repo_path, repo.created_at, 
            commits.cmt_author_email, commits.cmt_author_timestamp from repo, commits
        WHERE 
            repo.repo_id = commits.repo_id
        GROUP BY repo.repo_id, commits.cmt_commit_hash, commits.cmt_author_email, commits.cmt_author_timestamp
        """
all_commits = pd.read_sql_query(all_commits_query, con=engine)
all_commits
# Out:
#                                  cmt_commit_hash  repo_id repo_name  \
# 0       2e39564b13f157b711b4dac48c1fff4ecb9569e8    25469    scifio
# 1       6f7ca42dd86a023de52e34f6f4e9a491e8fd49da    25457    dealii
# 2       18e2a4961ad0ade33d0bb8082fbf0400763b7574    25450      sage
# 3       3f513cf1bb6d763e0ba667b97fdbeec6ebc3741e    25436  silver-1
# 4       95dcda13e465a7af045dc7a55e07e7f1aa5bad34    25450      sage
# ...                                          ...      ...       ...
# 498110  1184f279e67886d80e7ca72543c4d1de2fd933be    25448   boinc-1
# 498111  1fda62fab0ada494f9b94775c0f1eb2e2bfc6a14    25486     ADIOS
# 498112  d4d07fa38846202c8e94dfaffc1b960e64bd4f0c    25450      sage
# 498113  721c96632573081510754089b05137b6956f2edf    25450      sage
# 498114  623eb1ba76ba89b773943ab5f9b31e4422637d46    25457    dealii
#
#                     repo_path created_at                   cmt_author_email  \
# 0          github.com/scifio/       None               mark00bell@gmail.com
# 1          github.com/dealii/       None  bangerth@gluon.math.colostate.edu
# 2        github.com/sagemath/       None          martin.rubey@tuwien.ac.at
# 3        github.com/melt-umn/       None            tuxted+github@gmail.com
# 4        github.com/sagemath/       None           vincent.knight@gmail.com
# ...                       ...        ...                                ...
# 498110      github.com/BOINC/       None                 walton_rom@msn.com
# 498111  github.com/ornladios/       None                  daboyuka@ncsu.edu
# 498112   github.com/sagemath/       None                 tcscrims@gmail.com
# 498113   github.com/sagemath/       None        chapoton@math.univ-lyon1.fr
# 498114     github.com/dealii/       None  bangerth@gluon.math.colostate.edu
#
#              cmt_author_timestamp
# 0       2013-05-08 21:57:13+02:00
# 1       2011-03-25 02:40:53+01:00
# 2       2019-02-16 00:15:16+01:00
# 3       2018-08-07 21:01:10+02:00
# 4       2014-07-17 09:08:00+02:00
# ...                           ...
# 498110  2016-04-12 19:08:05+02:00
# 498111  2013-04-22 06:19:19+02:00
# 498112  2012-06-27 03:09:01+02:00
# 498113  2018-10-26 08:50:19+02:00
# 498114  2006-03-15 04:16:33+01:00
#
# [498115 rows x 7 columns]

# %%
test = pd.DataFrame()
test_query = f"""
        SELECT cntrb_login from contributors;
        """
test = pd.read_sql_query(test_query, con=engine)
test
# Out:
#         cntrb_login
# 0      not-provided
# 1             ctk3b
# 2     mattwthompson
# 3              None
# 4            ahy3nz
# ...             ...
# 9958       maggyero
# 9959         vitaut
# 9960          dfrib
# 9961        jacobsa
# 9962        glouppe
#
# [9963 rows x 1 columns]

# %%
    #by_repo = all_commits.loc[all_commits.groupby('repo_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
    by_repo = all_commits[all_commits.groupby('repo_id').cmt_author_timestamp.transform('max') == all_commits['cmt_author_timestamp']]
    
    import datetime

    current = datetime.date.today()
    start = current - datetime.timedelta(days=180)
    print(start)
    
    print(by_repo)
# Out:
# 2020-08-15
#                                  cmt_commit_hash  repo_id     repo_name  \
# 7697    516365866bc16ee9519e91d0c1d6c5ee7ad4cb9d    25492       tephra2
# 11654   b8c835bd52bbbfbd03193fdf072d9230a410d1ef    25507   rphash-java
# 55747   9b0aa57d7c9b89d7ebb9ea47778ff9b0a84257fd    25439  purdue-fastr
# 67850   2883ce5a9bc7b7a9f6c41ac3deb1ec21b79a4267    25510         OCCAM
# 69681   d02a858a76d0000b3b3012ffaeb6b04b2cf2a299    25457        dealii
# ...                                          ...      ...           ...
# 450452  40614457f25880a94d500b610d7c9dd9e99589b5    25444        tracer
# 452872  63ad4c0b50f077008eb33c7901495e900d8d1bc4    25445    CUDATracer
# 469123  783987b470967cc30c1794547276b19ea37c8e3a    25478    awp-odc-os
# 485998  f5de0040f89bfd330061d24448661200de9dbab5    25521   SimVascular
# 496522  56ed3a630907f3c30ecf780e1d506468275c87ea    25497          ompi
#
#                                      repo_path created_at  \
# 7697    github.com/geoscience-community-codes/       None
# 11654                     github.com/wilseypa/       None
# 55747                         github.com/allr/       None
# 67850                      github.com/SRI-CSL/       None
# 69681                       github.com/dealii/       None
# ...                                        ...        ...
# 450452                        github.com/allr/       None
# 452872                    github.com/linyufly/       None
# 469123                      github.com/hpgeoc/       None
# 485998                 github.com/SimVascular/       None
# 496522                    github.com/open-mpi/       None
#
#                         cmt_author_email       cmt_author_timestamp
# 7697                   laura@sanraf.site  2020-08-14 16:00:43+02:00
# 11654                  deysn@mail.uc.edu  2019-08-22 19:41:33+02:00
# 55747             kalibera@cs.purdue.edu  2015-06-17 09:02:21+02:00
# 67850              navasjorgea@gmail.com  2021-02-10 15:29:03+01:00
# 69681             peterrmuench@gmail.com  2021-02-10 17:07:17+01:00
# ...                                  ...                        ...
# 450452          ingo.korb@tu-dortmund.de  2017-06-08 12:45:56+02:00
# 452872  linyufly@linyufly-desktop.(none)  2014-09-06 17:10:34+02:00
# 469123                 anbreuer@sdsc.edu  2016-06-18 06:46:28+02:00
# 485998   parkerda@daves-mbp.attlocal.net  2021-02-07 03:21:02+01:00
# 496522             jjhursey@open-mpi.org  2021-02-09 16:27:41+01:00
#
# [61 rows x 7 columns]

# %%
# This gives us the top contribs per repo - this can be printed to csv file 
i=0
for index, row in by_repo.iterrows():
    repo_link = row.repo_path + row.repo_name
    org = row.repo_path.split("/")[1]
    print(repo_link, org)
    #print(row.repo_path, row.repo_name, row.cmt_author_timestamp, row.cmt_author_email)
    #print(type(row.cmt_author_timestamp))
    top_contribs = all_commits.loc[all_commits['repo_id'] == row.repo_id].cmt_author_email.value_counts()
    if len(top_contribs) > 1:
        print(top_contribs.index[0], top_contribs[0], top_contribs.index[1], top_contribs[1])
    elif len(top_contribs) == 1:
        print(top_contribs.index[0], top_contribs[0])
    elif len(top_contribs) == 0:
        print('None')
    i+=1
    if i == 50:
        break
# Out:
# github.com/geoscience-community-codes/tephra2 geoscience-community-codes
# laura@sanraf.site 121
# github.com/wilseypa/rphash-java wilseypa
# leecarraher@gmail.com 224 deysn@mail.uc.edu 33
# github.com/allr/purdue-fastr allr
# kalibera@cs.purdue.edu 711 florealm@gmail.com 84
# github.com/SRI-CSL/OCCAM SRI-CSL
# ian.mason@sri.com 606 navasjorgea@gmail.com 327
# github.com/dealii/dealii dealii
# bangerth@gluon.math.colostate.edu 18183 matthias.maier@iwr.uni-heidelberg.de 4018
# github.com/melt-umn/silver-1 melt-umn
# tuxted+github@gmail.com 1236 krame505@umn.edu 956
# github.com/oracle/fastr oracle
# Mick.Jordan@oracle.com 3007 lukas.stadler@oracle.com 2665
# github.com/geodynamics/aspect geodynamics
# bangerth@gluon.math.colostate.edu 2792 timo.heister@gmail.com 2650
# github.com/BOINC/boinc BOINC
# davidpanderson@users.noreply.github.com 9982 walton_rom@msn.com 7488
# github.com/CMU-Quake/hercules CMU-Quake
# ricardotaborda@users.noreply.github.com 33 rtaborda@cmu.edu 3
# github.com/pegasus-isi/pegasus pegasus-isi
# vahi@miralac3.fst.alcf.anl.gov 5960 rynge@isi.edu 1947
# github.com/PRUNERS/archer-1 PRUNERS
# simone@gmail.com 512 protze@itc.rwth-aachen.de 27
# github.com/diana-hep/oamap diana-hep
# jpivarski@users.noreply.github.com 991 jpivarski@gmail.com 31
# github.com/Paradigm4/SciDB Paradigm4
# ksen@paradigm4.com 9 dzhang@paradigm4.com 5
# github.com/trilinos/Trilinos trilinos
# bartlettra@ornl.gov 7658 mhoemmen@users.noreply.github.com 6158
# github.com/flame/libflame flame
# field@cs.utexas.edu 71 dieterich@ogolem.org 3
# github.com/yt-project/yt yt-project
# matthewturk@gmail.com 8392 jzuhone@gmail.com 2384
# github.com/diana-hep/carl diana-hep
# g.louppe@gmail.com 196 kyle.cranmer@cern.ch 16
# bitbucket.org/extasy-project/extasy-workflows/src/master/doc extasy-project
# vivek.balasubramanian@rutgers.edu 45 ardita.shkurti@gmail.com 6
# github.com/phys-tools/pi-qmc phys-tools
# john.shumwayjr@6df8c730-e442-11dd-8fb1-9960f2a117f8 309 john.shumwayjr@gmail.com 278
# github.com/scikit-hep/uproot scikit-hep
# jpivarski@users.noreply.github.com 1316 reikdas@gmail.com 430
# github.com/melt-umn/silver melt-umn
# tuxted+github@gmail.com 1236 krame505@umn.edu 956
# github.com/SCECcode/UCVMC SCECcode
# meisu@h2ologin1.ncsa.illinois.edu 449 pjmaechling@yahoo.com 81
# github.com/Reference-LAPACK/lapack Reference-LAPACK
# julielangou@users.noreply.github.com 454 langou@users.noreply.github.com 345
# github.com/BOINC/boinc-1 BOINC
# davidpanderson@users.noreply.github.com 9982 walton_rom@msn.com 7488
# github.com/wkbjerry/ulcc wkbjerry
# wangka@cse.ohio-state.edu 3
# github.com/cooperative-computing-lab/cctools cooperative-computing-lab
# tovar.benjamin@gmail.com 2839 dthain@vestalac1.ftd.alcf.anl.gov 1899
# github.com/landlab/landlab landlab
# huttone@colorado.edu 3006 katybarnhart@Katys-MacBook-Pro.local 1373
# github.com/wilseypa/rphash wilseypa
# wilseypa@gmail.com 5
# github.com/Geof23/Gklee Geof23
# peng@fractus.cs.utah.edu 77 fredericflintstone@gmail.com 34
# github.com/psi4/psi4 psi4
# loriab@6a214465-e6f0-41bc-91e6-de896bb96b5e 2709 malorian@me.com 1368
# github.com/cycronix/dataturbine cycronix
# fsbruva@yahoo.com 97 millermj1@comcast.net 57
# github.com/mosdef-hub/foyer-1 mosdef-hub
# christoph.klein@vanderbilt.edu 230 mattwthomp@gmail.com 201
# github.com/SCECcode/bbp SCECcode
# fsilva@broadband22.usc.edu 219 kmilner@usc.edu 5
# github.com/swift-lang/swift-k swift-lang
# hategan@mcs.anl.gov 3664 benc@hawaga.org.uk 1135
# github.com/sagemath/sage sagemath
# release@sagemath.org 12117 wstein@iras.sage.nea 5394
# github.com/PRUNERS/FLiT PRUNERS
# mbentley@llnl.gov 919 fredericflintstone@gmail.com 298
# github.com/allr/timeR allr
# ingo.korb@tu-dortmund.de 133
# github.com/sanshar/Block sanshar
# robolivares@gmail.com 128 sandeep@della3.(none) 88
# github.com/SCIInstitute/SCI-Solver_FEM SCIInstitute
# brigb123@users.noreply.github.com 87 payne.gene@gmail.com 56
# github.com/ornladios/ADIOS ornladios
# pnorbert@github.com 1292 pnorbert@ornl.gov 728
# github.com/cplusplus/concepts-ts cplusplus
# andrew.n.sutton@gmail.com 742 jason.merrill@gmail.com 50
# github.com/mosdef-hub/mbuild mosdef-hub
# christoph.klein@vanderbilt.edu 808 mattwthomp@gmail.com 324
# github.com/scifio/scifio scifio
# melissa@glencoesoftware.com 4490 ctrueden@wisc.edu 4130
# github.com/rocksclusters/FingerPrint rocksclusters
# lclementi@submit-1.batlab.org 614 jhayes@tscc-2-0.sdsc.edu 6
# github.com/GOMC-WSU/GOMC GOMC-WSU
# younesnejahi@gmail.com 961 younes@wayne.edu 467
# github.com/OpenMP/sources OpenMP
# michael.klemm@intel.com 1
# github.com/PRUNERS/archer PRUNERS
# simone@gmail.com 512 protze@itc.rwth-aachen.de 27
# github.com/henniggroup/gasp henniggroup
# wtipton@yaqh.localdomain 81 skw57@lithium.(none) 25
# bitbucket.org/chemora/chemoracode chemora
# koppel@ece.lsu.edu 483 marqs@man.poznan.pl 287

# %% [markdown]
# # Top Committers by Org

# %%
all_commits_query = f"""
        SELECT DISTINCT(commits.cmt_commit_hash), repo.repo_id, repo.repo_group_id, repo.repo_name, repo.repo_path, 
            commits.cmt_author_email, commits.cmt_author_timestamp from repo, commits
        WHERE 
            repo.repo_id = commits.repo_id
        GROUP BY repo.repo_id, commits.cmt_commit_hash, commits.cmt_author_email, commits.cmt_author_timestamp
        ORDER BY repo.repo_id;
        """
all_commits = pd.read_sql_query(all_commits_query, con=engine)
by_repo = all_commits.loc[all_commits.groupby('repo_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4d22fbcc143c> in <module>
#       8         """
#       9 all_commits = pd.read_sql_query(all_commits_query, con=engine)
# ---> 10 by_repo = all_commits.loc[all_commits.groupby('repo_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
#
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#     654             if self.obj.ndim == 1:
#     655                 # this can be called recursively, so need to raise ValueError
# --> 656                 raise ValueError
#     657
#     658             # GH#3688 try to operate item-by-item
#
# ValueError:

# %%
by_org = all_commits.loc[all_commits.groupby('repo_group_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
for index, row in by_org.iterrows():
    print 
    top_contribs = all_commits.loc[all_commits['repo_group_id'] == row.repo_group_id].cmt_author_email.value_counts()
    print(row.repo_path, top_contribs.index[0], top_contribs[0], top_contribs.index[1], top_contribs[1], top_contribs.index[2], top_contribs[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ecb124385061> in <module>
# ----> 1 by_org = all_commits.loc[all_commits.groupby('repo_group_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
#       2 for index, row in by_org.iterrows():
#       3     print
#       4     top_contribs = all_commits.loc[all_commits['repo_group_id'] == row.repo_group_id].cmt_author_email.value_counts()
#       5     print(row.repo_path, top_contribs.index[0], top_contribs[0], top_contribs.index[1], top_contribs[1], top_contribs.index[2], top_contribs[2])
#
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#     654             if self.obj.ndim == 1:
#     655                 # this can be called recursively, so need to raise ValueError
# --> 656                 raise ValueError
#     657
#     658             # GH#3688 try to operate item-by-item
#
# ValueError:

# %% [markdown]
# # Testing getting rid of more None values for gh login

# %%
    test_df = pd.DataFrame()
    test_df_query = f"""
            SELECT contributors.cntrb_login, contributors_aliases.canonical_email, 
                contributors_aliases.alias_email from contributors, contributors_aliases
            WHERE contributors_aliases.cntrb_id = contributors.cntrb_id
            """
    test_df = pd.read_sql_query(test_df_query, con=engine)

# %%
test_df
# Out:
#           cntrb_login                             canonical_email  \
# 0                None             raymat@master.cl.vanderbilt.edu
# 1                None             raymat@master.cl.vanderbilt.edu
# 2                None                      p.shama@vanderbilt.edu
# 3                None                        mattwthomp@gmail.com
# 4                None                          daico007@gmail.com
# ...               ...                                         ...
# 1387             None                        19100080@lums.edu.pk
# 1388             None                       ashish.gehani@sri.com
# 1389             None  38260180+shoaibCS@users.noreply.github.com
# 1390  umesh-timalsina                  umesh.timalsina@ioe.edu.np
# 1391             None                justin@localhost.localdomain
#
#                                       alias_email
# 0                  raymatsumoto@Macintosh-2.local
# 1                  ray.a.matsumoto@vanderbilt.edu
# 2     33552857+uppittu11@users.noreply.github.com
# 3                    matt.thompson@vanderbilt.edu
# 4      43968221+daico007@users.noreply.github.com
# ...                                           ...
# 1387   38260180+shoaibCS@users.noreply.github.com
# 1388                    gehani@shaman.csl.sri.com
# 1389                         19100080@lums.edu.pk
# 1390               umesh.timalsina@vanderbilt.edu
# 1391                    justin.b.gilmer@gmail.com
#
# [1392 rows x 3 columns]

# %%
i=0
for item in test_df.iterrows():
#    print(item[1].canonical_email)
#    print(item[1].alias_email)
    canonical_email = item[1].canonical_email
    alias_email = item[1].alias_email
    github_id = item[1].cntrb_login
    try:
        if id_dict[alias_email][0] is None:
            print(alias_email, 'is None, should be', github_id)
            id_dict[alias_email][0] = github_id
            print(alias_email, 'is now', id_dict[alias_email][0])
    except:
        print(alias_email, 'not found')
    try:
        id_dict[canonical_email][0]
    except:
        print(canonical_email, 'not found')
#    if i>100:
#        break
    i+=1
# Out:
# raymatsumoto@Macintosh-2.local is None, should be None
# raymatsumoto@Macintosh-2.local is now None
# ray.a.matsumoto@vanderbilt.edu is None, should be None
# ray.a.matsumoto@vanderbilt.edu is now None
# 33552857+uppittu11@users.noreply.github.com is None, should be None
# 33552857+uppittu11@users.noreply.github.com is now None
# matt.thompson@vanderbilt.edu is None, should be None
# matt.thompson@vanderbilt.edu is now None
# 43968221+daico007@users.noreply.github.com is None, should be None
# 43968221+daico007@users.noreply.github.com is now None
# janos.sallai@gmail.com is None, should be None
# janos.sallai@gmail.com is now None
# 54412158+Argon1999@users.noreply.github.com is None, should be None
# 54412158+Argon1999@users.noreply.github.com is now None
# raymat@master.cl.vanderbilt.edu is None, should be None
# raymat@master.cl.vanderbilt.edu is now None
# daico007@gmail.com is None, should be None
# daico007@gmail.com is now None
# jgilmer@g.clemson.edu is None, should be None
# jgilmer@g.clemson.edu is now None
# sallai.janos@vanderbilt.edu is None, should be None
# sallai.janos@vanderbilt.edu is now None
# arjun.bansal@vanderbilt.edu is None, should be None
# arjun.bansal@vanderbilt.edu is now None
# justin.b.gilmer@vanderbilt.edu is None, should be None
# justin.b.gilmer@vanderbilt.edu is now None
# krame505@users.noreply.github.com is None, should be None
# krame505@users.noreply.github.com is now None
# tedinski@cs.umn.edu is None, should be None
# tedinski@cs.umn.edu is now None
# p.shama@vanderbilt.edu is None, should be None
# p.shama@vanderbilt.edu is now None
# tuxted+github@gmail.com is None, should be None
# tuxted+github@gmail.com is now None
# travis.carlson@cs.umn.edu is None, should be TravisCarlson
# travis.carlson@cs.umn.edu is now TravisCarlson
# timothy.c.moore@vanderbilt.edu is None, should be tcmoore3
# timothy.c.moore@vanderbilt.edu is now tcmoore3
# peta.maj82@gmail.com is None, should be None
# peta.maj82@gmail.com is now None
# carl4980@umn.edu is None, should be None
# carl4980@umn.edu is now None
# evw@cs.umn.edu is None, should be ericvanwyk
# evw@cs.umn.edu is now ericvanwyk
# blanc317@umn.edu is None, should be JoeBlanchard
# blanc317@umn.edu is now JoeBlanchard
# daico007@Cos-MacBook-Air.local is None, should be None
# daico007@Cos-MacBook-Air.local is now None
# kalibera@gmail.com is None, should be None
# kalibera@gmail.com is now None
# christoph.klein@vanderbilt.edu is None, should be None
# christoph.klein@vanderbilt.edu is now None
# Peta@green is None, should be None
# Peta@green is now None
# alexander.h.yang@vanderbilt.edu is None, should be None
# alexander.h.yang@vanderbilt.edu is now None
# sallai@Janoss-MBP-2.lan is None, should be None
# sallai@Janoss-MBP-2.lan is now None
# jonestj1@vanderbilt.edu is None, should be None
# jonestj1@vanderbilt.edu is now None
# trevor.j.jones@vanderbilt.edu is None, should be None
# trevor.j.jones@vanderbilt.edu is now None
# jonestj1@dh-129-59-37-158.vuse.vanderbilt.edu is None, should be None
# jonestj1@dh-129-59-37-158.vuse.vanderbilt.edu is now None
# justin@localhost.localdomain is None, should be None
# justin@localhost.localdomain is now None
# jfoley@physics.utah.edu is None, should be None
# jfoley@physics.utah.edu is now None
# astrel@fnal.gov is None, should be None
# astrel@fnal.gov is now None
# cpviolator@users.noreply.github.com is None, should be None
# cpviolator@users.noreply.github.com is now None
# howarth@Penrose.tu.temple.edu is None, should be None
# howarth@Penrose.tu.temple.edu is now None
# rbabich@nvidia.com is None, should be None
# rbabich@nvidia.com is now None
# 2357719+cpviolator@users.noreply.github.com is None, should be None
# 2357719+cpviolator@users.noreply.github.com is now None
# serianam@gmail.com is None, should be None
# serianam@gmail.com is now None
# avaquero@cwg01.(none) is None, should be None
# avaquero@cwg01.(none) is now None
# evansweinberg@gmail.com is None, should be None
# evansweinberg@gmail.com is now None
# weinbe2@bu.edu is None, should be None
# weinbe2@bu.edu is now None
# evanweinberg@gmail.com is None, should be None
# evanweinberg@gmail.com is now None
# eweinberg@nvidia.com is None, should be None
# eweinberg@nvidia.com is now None
# fwinter@jlab.org is None, should be None
# fwinter@jlab.org is now None
# hpcfol01@login-sand5.xcat.cluster is None, should be None
# hpcfol01@login-sand5.xcat.cluster is now None
# christoph.t.klein@me.com is None, should be None
# christoph.t.klein@me.com is now None
# hpcfol01@login-sand3.xcat.cluster is None, should be None
# hpcfol01@login-sand3.xcat.cluster is now None
# hpcfol01@login-sand2.xcat.cluster is None, should be None
# hpcfol01@login-sand2.xcat.cluster is now None
# hpcfol01@login-sand8.xcat.cluster is None, should be None
# hpcfol01@login-sand8.xcat.cluster is now None
# hpcfol01@login-sand6.xcat.cluster is None, should be None
# hpcfol01@login-sand6.xcat.cluster is now None
# sallai@Janoss-MacBook-Pro-2.local is None, should be None
# sallai@Janoss-MacBook-Pro-2.local is now None
# hpcfol01@login-sand7.xcat.cluster is None, should be None
# hpcfol01@login-sand7.xcat.cluster is now None
# hpcfol01@login-sand1.xcat.cluster is None, should be None
# hpcfol01@login-sand1.xcat.cluster is now None
# u0731948@feynman.chpc.utah.edu is None, should be None
# u0731948@feynman.chpc.utah.edu is now None
# jfoley@ds1.fnal.gov is None, should be None
# jfoley@ds1.fnal.gov is now None
# u0731948@kepler2.chpc.utah.edu is None, should be None
# u0731948@kepler2.chpc.utah.edu is now None
# hpcfol01@login-sand4.xcat.cluster is None, should be None
# hpcfol01@login-sand4.xcat.cluster is now None
# jfoley@mic.fnal.gov is None, should be None
# jfoley@mic.fnal.gov is now None
# justin.foley@gmail.com is None, should be None
# justin.foley@gmail.com is now None
# root@093548ea-dc74-4ebb-8037-4be9f23db00a is None, should be None
# root@093548ea-dc74-4ebb-8037-4be9f23db00a is now None
# nicgaspar@093548ea-dc74-4ebb-8037-4be9f23db00a is None, should be None
# nicgaspar@093548ea-dc74-4ebb-8037-4be9f23db00a is now None
# nicolegasparini@ngaspari.tulane.edu is None, should be None
# nicolegasparini@ngaspari.tulane.edu is now None
# nicolegasparini@Nicoles-Mac-Pro.local is None, should be None
# nicolegasparini@Nicoles-Mac-Pro.local is now None
# jadams15@093548ea-dc74-4ebb-8037-4be9f23db00a is None, should be None
# jadams15@093548ea-dc74-4ebb-8037-4be9f23db00a is now None
# detar@home3.ccs.ornl.gov is None, should be None
# detar@home3.ccs.ornl.gov is now None
# jadams15@users.noreply.github.com is None, should be None
# jadams15@users.noreply.github.com is now None
# mcflugen@gmail.com is None, should be None
# mcflugen@gmail.com is now None
# mcflugen@users.noreply.github.com is None, should be None
# mcflugen@users.noreply.github.com is now None
# mathwagn@indiana.edu is None, should be None
# mathwagn@indiana.edu is now None
# nicgaspar@gmail.com is None, should be None
# nicgaspar@gmail.com is now None
# vagrant@vagrant.vm is None, should be None
# vagrant@vagrant.vm is now None
# gilles.m.duboscq@gmail.com is None, should be None
# gilles.m.duboscq@gmail.com is now None
# janos.sallai@vanderbilt.edu not found
# janos.sallai@vanderbilt.edu not found
# janos.sallai@vanderbilt.edu not found
# mathiasw@nvidia.com is None, should be None
# mathiasw@nvidia.com is now None
# tristan@external01.atlas.local is None, should be None
# tristan@external01.atlas.local is now None
# tristan.olive@studiodelta.us is None, should be None
# tristan.olive@studiodelta.us is now None
# micheng@enggrid1.BU.EDU is None, should be None
# micheng@enggrid1.BU.EDU is now None
# jadams15@tulane.edu is None, should be None
# jadams15@tulane.edu is now None
# micheng@bu.edu is None, should be None
# micheng@bu.edu is now None
# roman.katerinenko@oracle.com is None, should be None
# roman.katerinenko@oracle.com is now None
# manatsawin@gmail.com is None, should be None
# manatsawin@gmail.com is now None
# romw@us.ibm.com is None, should be None
# romw@us.ibm.com is now None
# rwalton@ssl.berkeley.edu is None, should be None
# rwalton@ssl.berkeley.edu is now None
# mike@hoffliet.local is None, should be None
# mike@hoffliet.local is now None
# daniel@v3061-0a9084c0.wifi.cf.ac.uk is None, should be None
# daniel@v3061-0a9084c0.wifi.cf.ac.uk is now None
# mikec@blast.bu.edu is None, should be None
# mikec@blast.bu.edu is now None
# dan.hobley@gmail.com is None, should be None
# dan.hobley@gmail.com is now None
# mikec@seas.harvard.edu is None, should be None
# mikec@seas.harvard.edu is now None
# bjoo@users.noreply.github.com is None, should be None
# bjoo@users.noreply.github.com is now None
# bjoo@jlab.org is None, should be None
# bjoo@jlab.org is now None
# bjoo@h2ologin2.ncsa.illinois.edu is None, should be None
# bjoo@h2ologin2.ncsa.illinois.edu is now None
# none@none is None, should be None
# none@none is now None
# frank.winter@ed.ac.uk is None, should be None
# frank.winter@ed.ac.uk is now None
# windy@windyserver.phy.bnl.gov is None, should be None
# windy@windyserver.phy.bnl.gov is now None
# windy510@gmail.com is None, should be None
# windy510@gmail.com is now None
# gshi@ac.(none) is None, should be None
# gshi@ac.(none) is now None
# gshi@cvrsvc06.(none) is None, should be None
# gshi@cvrsvc06.(none) is now None
# Mick.Jordan@oracle.com is None, should be None
# Mick.Jordan@oracle.com is now None
# gshi@jyc1.(none) is None, should be None
# gshi@jyc1.(none) is now None
# christian.beer@aei.mpg.de is None, should be None
# christian.beer@aei.mpg.de is now None
# gshi@login1.longhorn is None, should be None
# gshi@login1.longhorn is now None
# gshi@ncsa.uiuc.edu is None, should be None
# gshi@ncsa.uiuc.edu is now None
# chbeer@HNB544.aei.uni-hannover.de is None, should be None
# chbeer@HNB544.aei.uni-hannover.de is now None
# gshi@cvrsvc02.(none) is None, should be None
# gshi@cvrsvc02.(none) is now None
# gshi@cvrsvc05.(none) is None, should be None
# gshi@cvrsvc05.(none) is now None
# chris.schroeder@gmail.com is None, should be None
# chris.schroeder@gmail.com is now None
# weinbe2@users.noreply.github.com is None, should be None
# weinbe2@users.noreply.github.com is now None
# charliefenton@CharlieFs-MacPro.local is None, should be None
# charliefenton@CharlieFs-MacPro.local is now None
# daniel@dhmac.geol.cf.ac.uk is None, should be None
# daniel@dhmac.geol.cf.ac.uk is now None
# margauxmouchene@dhcp-216-251.tulane.edu is None, should be None
# margauxmouchene@dhcp-216-251.tulane.edu is now None
# margauxmouchene@dhcp-216-249.tulane.edu is None, should be None
# margauxmouchene@dhcp-216-249.tulane.edu is now None
# margauxmouchene@dhcp-216-222.tulane.edu is None, should be None
# margauxmouchene@dhcp-216-222.tulane.edu is now None
# ckachur@bitbucket.org is None, should be None
# ckachur@bitbucket.org is now None
# CKachur1105@gmail.com is None, should be None
# CKachur1105@gmail.com is now None
# margauxmouchene@Margauxs-iMac.local is None, should be None
# margauxmouchene@Margauxs-iMac.local is now None
# walton_rom@msn.com is None, should be None
# walton_rom@msn.com is now None
# dmhowarth26@gmail.com is None, should be None
# dmhowarth26@gmail.com is now None
# Jordan@Jordan-Adamss-MacBook-Pro.local is None, should be None
# Jordan@Jordan-Adamss-MacBook-Pro.local is now None
# micheng@enggrid2.bu.edu is None, should be None
# micheng@enggrid2.bu.edu is now None
# mick.jordan@oracle.com is None, should be None
# mick.jordan@oracle.com is now None
# ckachur@purdue.edu is None, should be None
# ckachur@purdue.edu is now None
# avaquero@ph04.(none) is None, should be None
# avaquero@ph04.(none) is now None
# margaux.mouchene@laposte.net is None, should be None
# margaux.mouchene@laposte.net is now None
# tolive@information-dynamics.com is None, should be None
# tolive@information-dynamics.com is now None
# katybarnhart@engr2-2-94-28-dhcp.int.colorado.edu is None, should be None
# katybarnhart@engr2-2-94-28-dhcp.int.colorado.edu is now None
# katy.barnhart@gmail.com is None, should be None
# katy.barnhart@gmail.com is now None
# bernd.machenschalk@aei.mpg.de is None, should be None
# bernd.machenschalk@aei.mpg.de is now None
# Bernd.Machenschalk@aei.mpg.de is None, should be None
# Bernd.Machenschalk@aei.mpg.de is now None
# vkoshura@lohika.com is None, should be None
# vkoshura@lohika.com is now None
# 31027858+Isira-Seneviratne@users.noreply.github.com is None, should be None
# 31027858+Isira-Seneviratne@users.noreply.github.com is now None
# joshi18@bitbucket.org not found
# njlyons@Icacos.local is None, should be None
# njlyons@Icacos.local is now None
# nathan.j.lyons@gmail.com is None, should be None
# nathan.j.lyons@gmail.com is now None
# brevilo@users.noreply.github.com is None, should be None
# brevilo@users.noreply.github.com is now None
# rtsegels@purdue.edu not found
# rytis.s@gmail.com is None, should be None
# rytis.s@gmail.com is now None
# jturney@jturney-Precision-WorkStation-T5400.(none) is None, should be None
# jturney@jturney-Precision-WorkStation-T5400.(none) is now None
# schroeder10@schroeder-mlt1.llnl.gov is None, should be None
# schroeder10@schroeder-mlt1.llnl.gov is now None
# bernd.machenschalk@ligo.org is None, should be None
# bernd.machenschalk@ligo.org is now None
# root@sirius.chem.vt.edu is None, should be None
# root@sirius.chem.vt.edu is now None
# Timo.Strunk@nanomatch.com is None, should be None
# Timo.Strunk@nanomatch.com is now None
# katybarnhart@Katys-MacBook-Pro.local is None, should be None
# katybarnhart@Katys-MacBook-Pro.local is now None
# sjrl@users.noreply.github.com is None, should be None
# sjrl@users.noreply.github.com is now None
# rbabich@bu.edu is None, should be None
# rbabich@bu.edu is now None
# 22824141+TheAspens@users.noreply.github.com is None, should be None
# 22824141+TheAspens@users.noreply.github.com is now None
# Jordan@e0-f8-47-11-a-8c.cg-guest.ucar.edu is None, should be None
# Jordan@e0-f8-47-11-a-8c.cg-guest.ucar.edu is now None
# mullinax@herzberg.ccqc.uga.edu is None, should be None
# mullinax@herzberg.ccqc.uga.edu is now None
# knreed@us.ibm.com is None, should be None
# knreed@us.ibm.com is now None
# ugur@ugur.gateway.2wire.net is None, should be None
# ugur@ugur.gateway.2wire.net is now None
# ugur@ugur.(none) is None, should be None
# ugur@ugur.(none) is now None
# huttone@colorado.edu is None, should be None
# huttone@colorado.edu is now None
# delionkur-lestat@mail.ru is None, should be None
# delionkur-lestat@mail.ru is now None
# gshi@acfs.(none) is None, should be None
# gshi@acfs.(none) is now None
# sergeyklay@users.noreply.github.com is None, should be None
# sergeyklay@users.noreply.github.com is now None
# francesco.evangelista@gmail.com is None, should be None
# francesco.evangelista@gmail.com is now None
# r.galvelis@acellera.com is None, should be None
# r.galvelis@acellera.com is now None
# andy.simmonett@gmail.com is None, should be None
# andy.simmonett@gmail.com is now None
# root@boincai05.cern.ch is None, should be None
# root@boincai05.cern.ch is now None
# andysim@ccc.uga.edu is None, should be None
# andysim@ccc.uga.edu is now None
# jussilehtola@fedoraproject.org is None, should be None
# jussilehtola@fedoraproject.org is now None
# susi.lehtola@gmail.com is None, should be None
# susi.lehtola@gmail.com is now None
# susi.lehtola@alumni.helsinki.fi is None, should be None
# susi.lehtola@alumni.helsinki.fi is now None
# m.scheurer@stud.uni-heidelberg.de is None, should be None
# m.scheurer@stud.uni-heidelberg.de is now None
# joobalint@gmail.com is None, should be None
# joobalint@gmail.com is now None
# deprince@lawn-128-61-122-22.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-122-22.lawn.gatech.edu is now None
# eheien@gmail.com is None, should be None
# eheien@gmail.com is now None
# root@isaac.ssl.berkeley.edu is None, should be None
# root@isaac.ssl.berkeley.edu is now None
# deprince@lawn-143-215-121-184.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-121-184.lawn.gatech.edu is now None
# deprince@kidlogin1.nics.utk.edu is None, should be None
# deprince@kidlogin1.nics.utk.edu is now None
# deprince@lawn-128-61-127-253.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-127-253.lawn.gatech.edu is now None
# deprince@lawn-128-61-125-182.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-125-182.lawn.gatech.edu is now None
# alexei@gtx-titan.fnal.gov is None, should be None
# alexei@gtx-titan.fnal.gov is now None
# deprince@lawn-128-61-122-73.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-122-73.lawn.gatech.edu is now None
# detar@physics.utah.edu is None, should be None
# detar@physics.utah.edu is now None
# deprince@lawn-128-61-127-238.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-127-238.lawn.gatech.edu is now None
# jiaxin@Jiaxins-MacBook-Pro.local is None, should be None
# jiaxin@Jiaxins-MacBook-Pro.local is now None
# dsambit@ln001.conflux.arc-ts.umich.edu is None, should be None
# dsambit@ln001.conflux.arc-ts.umich.edu is now None
# deprince@lawn-143-215-116-246.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-116-246.lawn.gatech.edu is now None
# deprince@lawn-128-61-115-145.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-115-145.lawn.gatech.edu is now None
# deprince@lawn-143-215-113-137.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-113-137.lawn.gatech.edu is now None
# deprince@lawn-128-61-116-92.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-116-92.lawn.gatech.edu is now None
# gruber@igpm.rwth-aachen.de is None, should be None
# gruber@igpm.rwth-aachen.de is now None
# deprince@lawn-128-61-118-180.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-118-180.lawn.gatech.edu is now None
# drwells@email.unc.edu is None, should be None
# drwells@email.unc.edu is now None
# booking.fridge@gmail.com is None, should be None
# booking.fridge@gmail.com is now None
# deprince@lawn-128-61-124-95.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-124-95.lawn.gatech.edu is now None
# drwells@vt.edu is None, should be None
# drwells@vt.edu is now None
# deprince@chem.fsu.edu is None, should be None
# deprince@chem.fsu.edu is now None
# deprince@lawn-143-215-113-204.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-113-204.lawn.gatech.edu is now None
# christian.beer@posteo.de is None, should be None
# christian.beer@posteo.de is now None
# deprince@lawn-128-61-118-160.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-118-160.lawn.gatech.edu is now None
# deprince@lawn-143-215-117-103.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-117-103.lawn.gatech.edu is now None
# deprince@lawn-128-61-112-203.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-112-203.lawn.gatech.edu is now None
# deprince@lawn-128-61-112-221.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-112-221.lawn.gatech.edu is now None
# deprince@lawn-143-215-112-187.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-112-187.lawn.gatech.edu is now None
# apache@isaac.ssl.berkeley.edu is None, should be None
# apache@isaac.ssl.berkeley.edu is now None
# agrayver@agrayver-VirtualBox.(none) is None, should be None
# agrayver@agrayver-VirtualBox.(none) is now None
# deprince@lawn-128-61-114-114.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-114-114.lawn.gatech.edu is now None
# deprince@lawn-128-61-119-22.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-119-22.lawn.gatech.edu is now None
# deprince@lawn-128-61-123-31.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-123-31.lawn.gatech.edu is now None
# deprince@lawn-128-61-119-143.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-119-143.lawn.gatech.edu is now None
# felgru@gmx.de is None, should be None
# felgru@gmx.de is now None
# deprince@lawn-128-61-121-114.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-121-114.lawn.gatech.edu is now None
# deprince@lawn-128-61-118-75.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-118-75.lawn.gatech.edu is now None
# deprince@lawn-128-61-112-143.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-112-143.lawn.gatech.edu is now None
# deprince@lawn-128-61-127-5.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-127-5.lawn.gatech.edu is now None
# mclark@nvidia.com is None, should be None
# mclark@nvidia.com is now None
# deprince@kidlogin2.nics.utk.edu is None, should be None
# deprince@kidlogin2.nics.utk.edu is now None
# deprince@lawn-143-215-113-237.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-113-237.lawn.gatech.edu is now None
# krishna.kumar@ucl.ac.uk is None, should be None
# krishna.kumar@ucl.ac.uk is now None
# deprince@lawn-143-215-117-111.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-117-111.lawn.gatech.edu is now None
# deprince@lawn-128-61-114-96.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-114-96.lawn.gatech.edu is now None
# krishnakumarg1984@users.noreply.github.com is None, should be None
# krishnakumarg1984@users.noreply.github.com is now None
# deprince@lawn-128-61-125-221.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-125-221.lawn.gatech.edu is now None
# deprince@lawn-143-215-117-183.lawn.gatech.edu is None, should be None
# deprince@lawn-143-215-117-183.lawn.gatech.edu is now None
# deprince@lawn-128-61-112-131.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-112-131.lawn.gatech.edu is now None
# deprince@lawn-128-61-118-161.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-118-161.lawn.gatech.edu is now None
# deprince@lawn-128-61-119-6.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-119-6.lawn.gatech.edu is now None
# deprince@Eugenes-MacBook-Pro.local is None, should be None
# deprince@Eugenes-MacBook-Pro.local is now None
# deprince@lawn-128-61-112-162.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-112-162.lawn.gatech.edu is now None
# isirasen96@gmail.com is None, should be None
# isirasen96@gmail.com is now None
# deprince@lawn-128-61-117-235.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-117-235.lawn.gatech.edu is now None
# deprince@lawn-128-61-121-51.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-121-51.lawn.gatech.edu is now None
# eugene.deprince@gmail.com is None, should be None
# eugene.deprince@gmail.com is now None
# laurence.field@cern.ch is None, should be None
# laurence.field@cern.ch is now None
# deprince@lawn-128-61-119-236.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-119-236.lawn.gatech.edu is now None
# w0ss4g3@gmail.com is None, should be None
# w0ss4g3@gmail.com is now None
# rosskynch@gmail.com is None, should be None
# rosskynch@gmail.com is now None
# maien@maien.uct.ac.za is None, should be None
# maien@maien.uct.ac.za is now None
# bangerth@math.tamu.edu is None, should be bangerth
# bangerth@math.tamu.edu is now bangerth
# bangerth@gluon.math.colostate.edu not found
# bangerth@gluon.math.colostate.edu not found
# lfield@cern.ch is None, should be None
# lfield@cern.ch is now None
# deprince@lawn-128-61-119-137.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-119-137.lawn.gatech.edu is now None
# shouck@vt.edu is None, should be None
# shouck@vt.edu is now None
# mlechner@gatech.edu is None, should be None
# mlechner@gatech.edu is now None
# francesco@Francescos-MacBook-Pro.local is None, should be None
# francesco@Francescos-MacBook-Pro.local is now None
# keith@uplinger.net is None, should be None
# keith@uplinger.net is now None
# uplink@us.ibm.com is None, should be None
# uplink@us.ibm.com is now None
# deprince@lawn-128-61-121-107.lawn.gatech.edu is None, should be None
# deprince@lawn-128-61-121-107.lawn.gatech.edu is now None
# charlief@example.com is None, should be None
# charlief@example.com is now None
# wellsd2@rpi.edu is None, should be None
# wellsd2@rpi.edu is now None
# rastak@stanford.edu is None, should be None
# rastak@stanford.edu is now None
# tal.regev@gmail.com is None, should be None
# tal.regev@gmail.com is now None
# apache@isaac.SSL.Berkeley.EDU is None, should be None
# apache@isaac.SSL.Berkeley.EDU is now None
# mclark@rmbp is None, should be None
# mclark@rmbp is now None
# manatsawin+git@gmail.com is None, should be None
# manatsawin+git@gmail.com is now None
# Laurence.Field@cern.ch is None, should be None
# Laurence.Field@cern.ch is now None
# rezarastak@users.noreply.github.com is None, should be None
# rezarastak@users.noreply.github.com is now None
# Germano0@users.noreply.github.com is None, should be None
# Germano0@users.noreply.github.com is now None
# davea@ssl.berkeley.edu is None, should be None
# davea@ssl.berkeley.edu is now None
# danw@ssl.berkeley.edu is None, should be None
# danw@ssl.berkeley.edu is now None
# Dan Werthimer@localhost is None, should be None
# Dan Werthimer@localhost is now None
# racuk12@gmail.com is None, should be None
# racuk12@gmail.com is now None
# germano.massullo@cern.ch is None, should be None
# germano.massullo@cern.ch is now None
# talregev@users.noreply.github.com is None, should be None
# talregev@users.noreply.github.com is now None
# theaspens0@gmail.com is None, should be None
# theaspens0@gmail.com is now None
# agrayver@erdw.ethz.ch is None, should be None
# agrayver@erdw.ethz.ch is now None
# ShanghaiTimes@users.noreply.github.com is None, should be None
# ShanghaiTimes@users.noreply.github.com is now None
# serghei@phalconphp.com is None, should be None
# serghei@phalconphp.com is now None
# krishnak@vt.edu is None, should be None
# krishnak@vt.edu is now None
# joachim.fritzsch@gmail.com is None, should be None
# joachim.fritzsch@gmail.com is now None
# davidpanderson@users.noreply.github.com is None, should be None
# davidpanderson@users.noreply.github.com is now None
# arndtd@ornl.gov is None, should be None
# arndtd@ornl.gov is now None
# d.arndt@math.uni-goettingen.de is None, should be None
# d.arndt@math.uni-goettingen.de is now None
# Giuseppe Pitton gpitton@sissa.it is None, should be None
# Giuseppe Pitton gpitton@sissa.it is now None
# gpitton@sissa.it is None, should be None
# gpitton@sissa.it is now None
# karl.ljungkvist@it.uu.se is None, should be None
# karl.ljungkvist@it.uu.se is now None
# marc.fehling@gmx.net is None, should be None
# marc.fehling@gmx.net is now None
# m.fehling@fz-juelich.de is None, should be None
# m.fehling@fz-juelich.de is now None
# matthias.maier@iwr.uni-heidelberg.de is None, should be None
# matthias.maier@iwr.uni-heidelberg.de is now None
# nicola.cavallini@unipv.it is None, should be None
# nicola.cavallini@unipv.it is now None
# stefano.dominici@mdlsoft.com is None, should be None
# stefano.dominici@mdlsoft.com is now None
# bangerth@gluon.math.colostate.edu not found
# hjkim@bnl.gov is None, should be None
# hjkim@bnl.gov is now None
# a.knieps@fz-juelich.de is None, should be None
# a.knieps@fz-juelich.de is now None
# alistairbntl@gmail.com is None, should be None
# alistairbntl@gmail.com is now None
# alistair.bntl@gmail.com is None, should be None
# alistair.bntl@gmail.com is now None
# tamiko@kyomu.43-1.org is None, should be None
# tamiko@kyomu.43-1.org is now None
# tamiko+GITHUB@kyomu.43-1.org is None, should be None
# tamiko+GITHUB@kyomu.43-1.org is now None
# kostyfisik@users.noreply.github.com is None, should be None
# kostyfisik@users.noreply.github.com is now None
# deprince@dirac13.(none) is None, should be None
# deprince@dirac13.(none) is now None
# sfndmn@gmail.com is None, should be None
# sfndmn@gmail.com is now None
# deprince@cvrsvc03.(none) is None, should be None
# deprince@cvrsvc03.(none) is now None
# deprince@cvrsvc01.(none) is None, should be None
# deprince@cvrsvc01.(none) is now None
# deprince@dirac19.(none) is None, should be None
# deprince@dirac19.(none) is now None
# tomaien@hotmail.com is None, should be None
# tomaien@hotmail.com is now None
# jbschri@emory.edu is None, should be None
# jbschri@emory.edu is now None
# protze@itc.rwth-aachen.de is None, should be None
# protze@itc.rwth-aachen.de is now None
# rkynch@gmail.com is None, should be None
# rkynch@gmail.com is now None
# protze1@llnl.gov is None, should be None
# protze1@llnl.gov is now None
# simone.at@gmail.com is None, should be None
# simone.at@gmail.com is now None
# atzeni1@llnl.gov is None, should be None
# atzeni1@llnl.gov is now None
# u0664236@utah.edu is None, should be None
# u0664236@utah.edu is now None
# 1364410+simoatze@users.noreply.github.com is None, should be None
# 1364410+simoatze@users.noreply.github.com is now None
# mafehling.git@gmail.com is None, should be None
# mafehling.git@gmail.com is now None
# luca-heltai@users.noreply.github.com not found
# simone@gmail.com is None, should be None
# simone@gmail.com is now None
# protze@rz.rwth-aachen.de is None, should be None
# protze@rz.rwth-aachen.de is now None
# zhrwang@rams.colostate.edu is None, should be None
# zhrwang@rams.colostate.edu is now None
# zhuoranwang@ZhuorandeMacBook-Pro.local is None, should be None
# zhuoranwang@ZhuorandeMacBook-Pro.local is now None
# stark.sebastian@gmx.de is None, should be None
# stark.sebastian@gmx.de is now None
# luca.heltai@gmail.com is None, should be luca-heltai
# luca.heltai@gmail.com is now luca-heltai
# luca-heltai@users.noreply.github.com not found
# root@localhost.localdomain is None, should be None
# root@localhost.localdomain is now None
# oneliefleft@gmail.com is None, should be None
# oneliefleft@gmail.com is now None
# root@dhcp46-211.ipam.ucla.edu is None, should be None
# root@dhcp46-211.ipam.ucla.edu is now None
# root@achille.loria.fr is None, should be None
# root@achille.loria.fr is now None
# root@mpc739.mati.uni-jena.de is None, should be None
# root@mpc739.mati.uni-jena.de is now None
# root@sage is None, should be None
# root@sage is now None
# seb.oehms@gmail.com is None, should be None
# seb.oehms@gmail.com is now None
# deprince@dirac26.(none) is None, should be None
# deprince@dirac26.(none) is now None
# mike@mike-laptop is None, should be None
# mike@mike-laptop is now None
# isuru.11@cse.mrt.ac.lk is None, should be None
# isuru.11@cse.mrt.ac.lk is now None
# daniel.arndt@iwr.uni-heidelberg.de is None, should be None
# daniel.arndt@iwr.uni-heidelberg.de is now None
# D.Loeffler@dpmms.cam.ac.uk is None, should be None
# D.Loeffler@dpmms.cam.ac.uk is now None
# bbakr@tompro2.local is None, should be None
# bbakr@tompro2.local is now None
# dave.loeffler@gmail.com is None, should be None
# dave.loeffler@gmail.com is now None
# brandon.bakr@gmail.com is None, should be None
# brandon.bakr@gmail.com is now None
# ryanmrichard1@gmail.com is None, should be None
# ryanmrichard1@gmail.com is now None
# david.loeffler05@imperial.ac.uk is None, should be None
# david.loeffler05@imperial.ac.uk is now None
# d.loeffler.01@cantab.net is None, should be None
# d.loeffler.01@cantab.net is now None
# lukas.stennes@rub.de is None, should be None
# lukas.stennes@rub.de is now None
# charles.bouillaguet@univ-lille1.fr is None, should be None
# charles.bouillaguet@univ-lille1.fr is now None
# charles.bouillaguet@gmail.com is None, should be None
# charles.bouillaguet@gmail.com is now None
# hinerm@gmail.com is None, should be None
# hinerm@gmail.com is now None
# darijgrinberg@gmail.com is None, should be None
# darijgrinberg@gmail.com is now None
# workonly@qidane.com is None, should be None
# workonly@qidane.com is now None
# virmaux@lri.com is None, should be None
# virmaux@lri.com is now None
# callan@blackcat.ca is None, should be None
# callan@blackcat.ca is now None
# aladin.virmaux@gmail.com is None, should be None
# aladin.virmaux@gmail.com is now None
# callan@glencoesoftware.com is None, should be None
# callan@glencoesoftware.com is now None
# vivianepons at gmail.com is None, should be None
# vivianepons at gmail.com is now None
# pons at univ-mlv.fr not found
# viviane@pons-ThinkCentre-M58p is None, should be None
# viviane@pons-ThinkCentre-M58p is now None
# jenkins@dev.loci.wisc.edu is None, should be None
# jenkins@dev.loci.wisc.edu is now None
# czheng2@disc03.crc.nd.edu is None, should be None
# czheng2@disc03.crc.nd.edu is now None
# czheng2@disc01.crc.nd.edu is None, should be None
# czheng2@disc01.crc.nd.edu is now None
# czheng2@disc04.crc.nd.edu is None, should be None
# czheng2@disc04.crc.nd.edu is now None
# richard-github@metafoo.co.uk is None, should be None
# richard-github@metafoo.co.uk is now None
# ksweene3@cclws19.cse.nd.edu is None, should be None
# ksweene3@cclws19.cse.nd.edu is now None
# devel@danielkrenn.at is None, should be None
# devel@danielkrenn.at is now None
# git@danielkrenn.at is None, should be None
# git@danielkrenn.at is now None
# math@danielkrenn.at is None, should be None
# math@danielkrenn.at is now None
# richard@metafoo.co.uk is None, should be None
# richard@metafoo.co.uk is now None
# gabriel.einsdorf@uni.kn not found
# hmeng@nd.edu is None, should be None
# hmeng@nd.edu is now None
# hmeng@earth.crc.nd.edu is None, should be None
# hmeng@earth.crc.nd.edu is now None
# hmeng@cclws03.cse.nd.edu is None, should be None
# hmeng@cclws03.cse.nd.edu is now None
# Johannes.Schindelin@gmx.de not found
# peter.j.bui@gmail.com is None, should be None
# peter.j.bui@gmail.com is now None
# emily.gunawan@gmail.com is None, should be None
# emily.gunawan@gmail.com is now None
# martin@road is None, should be None
# martin@road is now None
# anbreuer@ucsd.edu is None, should be None
# anbreuer@ucsd.edu is now None
# czheng2@disc02.crc.nd.edu is None, should be None
# czheng2@disc02.crc.nd.edu is now None
# breuera@in.tum.de is None, should be None
# breuera@in.tum.de is now None
# vit.tucek+sagemath@gmail.com is None, should be None
# vit.tucek+sagemath@gmail.com is now None
# dthain@vestalac1.ftd.alcf.anl.gov is None, should be None
# dthain@vestalac1.ftd.alcf.anl.gov is now None
# vit-tucek@users.noreply.github.com is None, should be None
# vit-tucek@users.noreply.github.com is now None
# dthain@dthain-macbook.local is None, should be None
# dthain@dthain-macbook.local is now None
# mei@hpc-login3.hpcc.usc.edu is None, should be None
# mei@hpc-login3.hpcc.usc.edu is now None
# vit.tucek@gmail.com is None, should be None
# vit.tucek@gmail.com is now None
# meisu@h2ologin4.ncsa.illinois.edu is None, should be None
# meisu@h2ologin4.ncsa.illinois.edu is now None
# vincent.delecroix@labri.fr is None, should be None
# vincent.delecroix@labri.fr is now None
# meisu@h2ologin3.ncsa.illinois.edu is None, should be None
# meisu@h2ologin3.ncsa.illinois.edu is now None
# 20100.delecroix at gmail.com is None, should be None
# 20100.delecroix at gmail.com is now None
# mei@titan-ext2.ccs.ornl.gov is None, should be None
# mei@titan-ext2.ccs.ornl.gov is now None
# mei@intensity.usc.edu is None, should be None
# mei@intensity.usc.edu is now None
# mei@hpc4102.hpcc.usc.edu is None, should be None
# mei@hpc4102.hpcc.usc.edu is now None
# mei@hpc3789.hpcc.usc.edu is None, should be None
# mei@hpc3789.hpcc.usc.edu is now None
# mei@titan-ext7.ccs.ornl.gov is None, should be None
# mei@titan-ext7.ccs.ornl.gov is now None
# mei@hpc4482.hpcc.usc.edu is None, should be None
# mei@hpc4482.hpcc.usc.edu is now None
# mei@MeiPro.local is None, should be None
# mei@MeiPro.local is now None
# mei@hpc1407.hpcc.usc.edu is None, should be None
# mei@hpc1407.hpcc.usc.edu is now None
# meisu@h2ologin2.ncsa.illinois.edu is None, should be None
# meisu@h2ologin2.ncsa.illinois.edu is now None
# mei@titan-ext5.ccs.ornl.gov is None, should be None
# mei@titan-ext5.ccs.ornl.gov is now None
# mei@broadbandclone.usc.edu is None, should be None
# mei@broadbandclone.usc.edu is now None
# Dean Bisogno is None, should be notcoffeetable
# Dean Bisogno is now notcoffeetable
# d.ben.antieau@gmail.com is None, should be None
# d.ben.antieau@gmail.com is now None
# meisu@h2ologin1.ncsa.illinois.edu is None, should be None
# meisu@h2ologin1.ncsa.illinois.edu is now None
# batrick@batbytes.com is None, should be None
# batrick@batbytes.com is now None
# batrick@users.noreply.github.com is None, should be None
# batrick@users.noreply.github.com is now None
# maechlin@hpc-login2-l.hpcc.usc.edu is None, should be None
# maechlin@hpc-login2-l.hpcc.usc.edu is now None
# pjmaechling@users.noreply.github.com is None, should be None
# pjmaechling@users.noreply.github.com is now None
# pjmaechling@gmail.com is None, should be None
# pjmaechling@gmail.com is now None
# cloud9@641.be is None, should be None
# cloud9@641.be is now None
# maurizio.monge@im.ufrj.br is None, should be None
# maurizio.monge@im.ufrj.br is now None
# rparrish6@force.pace.gatech.edu is None, should be None
# rparrish6@force.pace.gatech.edu is now None
# tshaffe1@nd.edu is None, should be None
# tshaffe1@nd.edu is now None
# VulK@parsip.fourlands is None, should be None
# VulK@parsip.fourlands is now None
# stella@math.haifa.ac.il is None, should be None
# stella@math.haifa.ac.il is now None
# ben@robotoloco.com is None, should be None
# ben@robotoloco.com is now None
# kini@member.ams.org is None, should be None
# kini@member.ams.org is now None
# martinralbrecht@googlemail.com is None, should be None
# martinralbrecht@googlemail.com is now None
# trshaffer@users.noreply.github.com is None, should be None
# trshaffer@users.noreply.github.com is now None
# felix@em.cs.uni-frankfurt.de is None, should be None
# felix@em.cs.uni-frankfurt.de is now None
# vincent.neiger@unilim.fr is None, should be None
# vincent.neiger@unilim.fr is now None
# kmulholl@student02.cse.nd.edu is None, should be None
# kmulholl@student02.cse.nd.edu is now None
# kmulholl@brahms.helios.nd.edu is None, should be None
# kmulholl@brahms.helios.nd.edu is now None
# kmulholl@cclws05.cse.nd.edu is None, should be None
# kmulholl@cclws05.cse.nd.edu is now None
# andrew dot mathas at sydney dot com dot au is None, should be None
# andrew dot mathas at sydney dot com dot au is now None
# andrew dot mathas at sydney dot edu dot au is None, should be None
# andrew dot mathas at sydney dot edu dot au is now None
# andrew.mathas at sydney.edu.au is None, should be None
# andrew.mathas at sydney.edu.au is now None
# kmulholl@student00.cse.nd.edu is None, should be None
# kmulholl@student00.cse.nd.edu is now None
# egunawan@umn.edu is None, should be None
# egunawan@umn.edu is now None
# math+sage@danielkrenn.at is None, should be None
# math+sage@danielkrenn.at is now None
# dthain@nd.edu is None, should be None
# dthain@nd.edu is now None
# kantor@c-71-227-164-229.hsd1.wa.comcast.net is None, should be None
# kantor@c-71-227-164-229.hsd1.wa.comcast.net is now None
# kantor@josh-kantors-macbook.local is None, should be None
# kantor@josh-kantors-macbook.local is now None
# kantor@c-24-17-242-239.hsd1.mn.comcast.net is None, should be None
# kantor@c-24-17-242-239.hsd1.mn.comcast.net is now None
# pjmaechling@yahoo.com is None, should be None
# pjmaechling@yahoo.com is now None
# kantor@jkantor-laptop is None, should be None
# kantor@jkantor-laptop is now None
# kantor@cpe-76-180-115-46.buffalo.res.rr.com is None, should be None
# kantor@cpe-76-180-115-46.buffalo.res.rr.com is now None
# bhutz@gc.cuny.edu is None, should be None
# bhutz@gc.cuny.edu is now None
# baguage@gmail.com is None, should be None
# baguage@gmail.com is now None
# mullinax@uga.edu is None, should be None
# mullinax@uga.edu is now None
# bn4941@gmail.com is None, should be None
# bn4941@gmail.com is now None
# chrisjamesberg@gmail.com is None, should be None
# chrisjamesberg@gmail.com is now None
# jkantor@localhost is None, should be None
# jkantor@localhost is now None
# kli3@nd.edu is None, should be None
# kli3@nd.edu is now None
# jkantor@sage.math.washington.edu is None, should be None
# jkantor@sage.math.washington.edu is now None
# crawdad@vt.edu is None, should be None
# crawdad@vt.edu is now None
# clement.pernet@gmail.com is None, should be None
# clement.pernet@gmail.com is now None
# jeffschriber@users.noreply.github.com is None, should be None
# jeffschriber@users.noreply.github.com is now None
# ccarball@nd.edu is None, should be None
# ccarball@nd.edu is now None
# pdonnel3@nd.edu is None, should be None
# pdonnel3@nd.edu is now None
# adrien.boussicault@labri.fr is None, should be None
# adrien.boussicault@labri.fr is now None
# jason.grout@drake.edu is None, should be None
# jason.grout@drake.edu is now None
# jason-sage@creativetrax.com is None, should be None
# jason-sage@creativetrax.com is now None
# peterjeremy@acm.org is None, should be None
# peterjeremy@acm.org is now None
# grout@rayunion.org is None, should be None
# grout@rayunion.org is now None
# rober.harron@gmail.com is None, should be None
# rober.harron@gmail.com is now None
# nkremerh@nd.edu is None, should be None
# nkremerh@nd.edu is now None
# William Stein@windows is None, should be None
# William Stein@windows is now None
# wstein@ucsd.edu is None, should be None
# wstein@ucsd.edu is now None
# pnutzh4x0r@gmail.com is None, should be None
# pnutzh4x0r@gmail.com is now None
# wstein@uw.edu is None, should be None
# wstein@uw.edu is now None
# wstein@pdlc424.local is None, should be None
# wstein@pdlc424.local is now None
# wstein@teragon.local is None, should be None
# wstein@teragon.local is now None
# wstein@gmail.com and martinralbrecht is None, should be None
# wstein@gmail.com and martinralbrecht is now None
# wstein@zeno1.math.washington.edu is None, should be None
# wstein@zeno1.math.washington.edu is now None
# wstein@gmail.com is None, should be None
# wstein@gmail.com is now None
# tovar.benjamin@gmail.com is None, should be None
# tovar.benjamin@gmail.com is now None
# wstein@oto.local is None, should be None
# wstein@oto.local is now None
# wstein@cicero.sagenet.site is None, should be None
# wstein@cicero.sagenet.site is now None
# Baguage@users.noreply.github.com is None, should be None
# Baguage@users.noreply.github.com is now None
# wstein@localhost.localdomain is None, should be None
# wstein@localhost.localdomain is now None
# kedlaya@mit.edu is None, should be None
# kedlaya@mit.edu is now None
# ondrej@raven is None, should be None
# ondrej@raven is now None
# drake@mathsci.kaist.ac.kr is None, should be None
# drake@mathsci.kaist.ac.kr is now None
# nkremerh@users.noreply.github.com is None, should be None
# nkremerh@users.noreply.github.com is now None
# dr.dan.drake@gmail.com is None, should be None
# dr.dan.drake@gmail.com is now None
# ddrake@member.ams.org is None, should be None
# ddrake@member.ams.org is now None
# drake@kaist.edu is None, should be None
# drake@kaist.edu is now None
# bruce.westbury@gmail.com is None, should be None
# bruce.westbury@gmail.com is now None
# atovtchi@jcvi.org is None, should be None
# atovtchi@jcvi.org is now None
# 20100.delecroix@gmail.com is None, should be None
# 20100.delecroix@gmail.com is now None
# rharron@math.wisc.edu is None, should be None
# rharron@math.wisc.edu is now None
# mabshoff@fermat.math.harvard.edu is None, should be None
# mabshoff@fermat.math.harvard.edu is now None
# kli3@cclws17.cse.nd.edu is None, should be None
# kli3@cclws17.cse.nd.edu is now None
# mabshoff@mark.sagenet.site is None, should be None
# mabshoff@mark.sagenet.site is now None
# mabshoff@michael-abshoffs-ibook-g4.local is None, should be None
# mabshoff@michael-abshoffs-ibook-g4.local is now None
# mabshoff@localhost is None, should be None
# mabshoff@localhost is now None
# mabshoff@iras.sage.nea is None, should be None
# mabshoff@iras.sage.nea is now None
# mabshoff@localhost.localdomain is None, should be None
# mabshoff@localhost.localdomain is now None
# mabshoff@sage.math.washington.edu is None, should be None
# mabshoff@sage.math.washington.edu is now None
# mabshoff@modular is None, should be None
# mabshoff@modular is now None
# andreyto@gmail.com is None, should be None
# andreyto@gmail.com is now None
# mabshoff@varro is None, should be None
# mabshoff@varro is now None
# mabshoff@geom.math.washington.edu is None, should be None
# mabshoff@geom.math.washington.edu is now None
# mabshoff@fulvia is None, should be None
# mabshoff@fulvia is now None
# mabshoff@bsd.local is None, should be None
# mabshoff@bsd.local is now None
# mabshoff@sage is None, should be None
# mabshoff@sage is now None
# mabshoff@opensuse64 is None, should be None
# mabshoff@opensuse64 is now None
# ksweene3@cclws07.cse.nd.edu is None, should be None
# ksweene3@cclws07.cse.nd.edu is now None
# slabqc at gmail.com is None, should be None
# slabqc at gmail.com is now None
# pernet@john is None, should be None
# pernet@john is now None
# pernet@sage.math.washington.edu is None, should be None
# pernet@sage.math.washington.edu is now None
# ayr035@gmail.com is None, should be None
# ayr035@gmail.com is now None
# sandeep@hecate.princeton.edu is None, should be None
# sandeep@hecate.princeton.edu is now None
# sharma@allogin1.fkf.mpg.de is None, should be None
# sharma@allogin1.fkf.mpg.de is now None
# sandeepsharma@nat-oitwireless-inside-vapornet100-d-19708.princeton.edu is None, should be None
# sandeepsharma@nat-oitwireless-inside-vapornet100-d-19708.princeton.edu is now None
# zbxthu@gmail.com not found
# sharma@pcal009.fkf.mpg.de is None, should be None
# sharma@pcal009.fkf.mpg.de is now None
# sanshar@gmail.com is None, should be None
# sanshar@gmail.com is now None
# sandeepsharma@Sandeeps-MacBook-Air.local is None, should be None
# sandeepsharma@Sandeeps-MacBook-Air.local is now None
# sash2458@bnode0307.rc.int.colorado.edu is None, should be None
# sash2458@bnode0307.rc.int.colorado.edu is now None
# sandeepsharma@nat-oitwireless-inside-vapornet100-a-23843.princeton.edu is None, should be None
# sandeepsharma@nat-oitwireless-inside-vapornet100-a-23843.princeton.edu is now None
# sharma@chan-perceus.localdomain is None, should be None
# sharma@chan-perceus.localdomain is now None
# virmaux@lri.fr is None, should be None
# virmaux@lri.fr is now None
# jason.merrill@gmail.com is None, should be jicama
# jason.merrill@gmail.com is now jicama
# cartec69@gmail.com is None, should be CaseyCarter
# cartec69@gmail.com is now CaseyCarter
# cacarter@microsoft.com is None, should be CaseyCarter
# cacarter@microsoft.com is now CaseyCarter
# sandeep@della3.(none) is None, should be None
# sandeep@della3.(none) is now None
# ugur@ub.gateway.2wire.net is None, should be None
# ugur@ub.gateway.2wire.net is now None
# n.nakatani0608@gmail.com is None, should be None
# n.nakatani0608@gmail.com is now None
# pancratz@maths.ox.ac.uk is None, should be None
# pancratz@maths.ox.ac.uk is now None
# sage@pancratz is None, should be None
# sage@pancratz is now None
# ssivek@math.mit.edu is None, should be None
# ssivek@math.mit.edu is now None
# 12844423+seb-mtl@users.noreply.github.com is None, should be None
# 12844423+seb-mtl@users.noreply.github.com is now None
# ddrake@math.wisc.edu is None, should be None
# ddrake@math.wisc.edu is now None
# richardsmith@google.com is None, should be None
# richardsmith@google.com is now None
# jwakely@getcollc.com is None, should be None
# jwakely@getcollc.com is now None
# github@kayari.org is None, should be None
# github@kayari.org is now None
# jwakely@redhat.com is None, should be None
# jwakely@redhat.com is now None
# hstong@ibm is None, should be None
# hstong@ibm is now None
# hubert-reinterpretcast@users.noreply.github.com is None, should be None
# hubert-reinterpretcast@users.noreply.github.com is now None
# github@jfbastien.com is None, should be None
# github@jfbastien.com is now None
# jfb@chromium.org is None, should be None
# jfb@chromium.org is now None
# charles.bouillaguet@lifl.fr is None, should be None
# charles.bouillaguet@lifl.fr is now None
# mhansen@gmail.com is None, should be None
# mhansen@gmail.com is now None
# gjorgenson2013@my.fit.edu is None, should be None
# gjorgenson2013@my.fit.edu is now None
# kantor@389.local is None, should be None
# kantor@389.local is now None
# was@arch is None, should be None
# was@arch is now None
# public@alisdairm.net is None, should be None
# public@alisdairm.net is now None
# was@d-128-95-230-115.dhcp4.washington.edu is None, should be None
# was@d-128-95-230-115.dhcp4.washington.edu is now None
# was@eight.math.washington.edu is None, should be None
# was@eight.math.washington.edu is now None
# was@leibniz.math.harvard.edu is None, should be None
# was@leibniz.math.harvard.edu is now None
# was@newserver.math.harvard.edu is None, should be None
# was@newserver.math.harvard.edu is now None
# was@fermat.math.harvard.edu is None, should be None
# was@fermat.math.harvard.edu is now None
# naokin@ferrum.(none) is None, should be None
# naokin@ferrum.(none) is now None
# was@ubuntu is None, should be None
# was@ubuntu is now None
# was@keyah.local is None, should be None
# was@keyah.local is now None
# was@neron.math.harvard.edu is None, should be None
# was@neron.math.harvard.edu is now None
# was@rhel32 is None, should be None
# was@rhel32 is now None
# masaaki_saitow@yahoo.co.jp is None, should be None
# masaaki_saitow@yahoo.co.jp is now None
# was@localhost.localdomain is None, should be None
# was@localhost.localdomain is now None
# was@meccah4.math.harvard.edu is None, should be None
# was@meccah4.math.harvard.edu is now None
# masaaki@Osiris2.local is None, should be None
# masaaki@Osiris2.local is now None
# was@suse is None, should be None
# was@suse is now None
# jayagarwal@Vex.local is None, should be None
# jayagarwal@Vex.local is now None
# jfbastien@apple.com is None, should be None
# jfbastien@apple.com is now None
# was@ubuntu.localdomain is None, should be None
# was@ubuntu.localdomain is now None
# was@sha.local is None, should be None
# was@sha.local is now None
# sjdutoit@gmail.com is None, should be None
# sjdutoit@gmail.com is now None
# ...
# micheldemessieres@laptop.home is now None
# mildewey@pyro.eti is None, should be None
# mildewey@pyro.eti is now None
# mwdewe@sandia.gov is None, should be None
# mwdewe@sandia.gov is now None
# phtsuji@unknown247703c5416c.gateway.2wire.net is None, should be None
# phtsuji@unknown247703c5416c.gateway.2wire.net is now None
# phtsuji@sandia.gov is None, should be None
# phtsuji@sandia.gov is now None
# mperego@s1026095.srn.sandia.gov is None, should be None
# mperego@s1026095.srn.sandia.gov is now None
# grahambenharper@gmail.com is None, should be None
# grahambenharper@gmail.com is now None
# ianbriggs@comcast.net is None, should be None
# ianbriggs@comcast.net is now None
# ianbriggs@line-ibriggs.cs.utah.edu is None, should be None
# ianbriggs@line-ibriggs.cs.utah.edu is now None
# ianbriggsutah@gmail.com is None, should be None
# ianbriggsutah@gmail.com is now None
# 2159992+IanBriggs@users.noreply.github.com is None, should be None
# 2159992+IanBriggs@users.noreply.github.com is now None
# sawaya@node.sawaya-qv9066.qfp-pg0.utah.cloudlab.us is None, should be None
# sawaya@node.sawaya-qv9066.qfp-pg0.utah.cloudlab.us is now None
# sawaya@node.sawaya-qv23144.qfp-pg0.utah.cloudlab.us is None, should be None
# sawaya@node.sawaya-qv23144.qfp-pg0.utah.cloudlab.us is now None
# sawaya@node.sawaya-qv23082.qfp-pg0.utah.cloudlab.us is None, should be None
# sawaya@node.sawaya-qv23082.qfp-pg0.utah.cloudlab.us is now None
# sawaya@node.sawaya-qv23142.qfp-pg0.utah.cloudlab.us is None, should be None
# sawaya@node.sawaya-qv23142.qfp-pg0.utah.cloudlab.us is now None
# ian.briggs@utah.edu is None, should be None
# ian.briggs@utah.edu is now None
# sawaya@fractus.cs.utah.edu is None, should be None
# sawaya@fractus.cs.utah.edu is now None
# sawaya@login1.stampede.tacc.utexas.edu is None, should be None
# sawaya@login1.stampede.tacc.utexas.edu is now None
# sawaya@c557-202.stampede.tacc.utexas.edu is None, should be None
# sawaya@c557-202.stampede.tacc.utexas.edu is now None
# geof23@github.com is None, should be None
# geof23@github.com is now None
# sawaya@login4.stampede.tacc.utexas.edu is None, should be None
# sawaya@login4.stampede.tacc.utexas.edu is now None
# geof.sawaya@gmail.com is None, should be None
# geof.sawaya@gmail.com is now None
# alexander.heinlein@uni-köln.de not found
# aprokop@users.noreply.github.com is None, should be None
# aprokop@users.noreply.github.com is now None
# prokopenkoav@ornl.gov is None, should be None
# prokopenkoav@ornl.gov is now None
# aprokop@sandia.gov is None, should be None
# aprokop@sandia.gov is now None
# bcarnes is None, should be None
# bcarnes is now None
# cag@cag is None, should be None
# cag@cag is now None
# cgcgcg@users.noreply.github.com is None, should be None
# cgcgcg@users.noreply.github.com is now None
# jmwille@sandia.gov is None, should be None
# jmwille@sandia.gov is now None
# mbentley@llnl.gov is None, should be None
# mbentley@llnl.gov is now None
# mikebentley15@gmail.com is None, should be None
# mikebentley15@gmail.com is now None
# mmayr@sandia.gov is None, should be None
# mmayr@sandia.gov is now None
# pohm@albeniz.srn.sandia.gov is None, should be None
# pohm@albeniz.srn.sandia.gov is now None
# pohm@enigma.sandia.gov is None, should be None
# pohm@enigma.sandia.gov is now None
# raoldfi@sandia.gov is None, should be None
# raoldfi@sandia.gov is now None
# gahanse@sandia.gov is None, should be None
# gahanse@sandia.gov is now None
# jhu@sandia.gov is None, should be None
# jhu@sandia.gov is now None
# bentley8@llnl.gov is None, should be None
# bentley8@llnl.gov is now None
# trbenson413@gmail.com is None, should be None
# trbenson413@gmail.com is now None
# ubuntu@gc-stoic-darwin.novalocal is None, should be None
# ubuntu@gc-stoic-darwin.novalocal is now None
# ynejahi@Youness-MacBook-Pro.local is None, should be None
# ynejahi@Youness-MacBook-Pro.local is now None
# younes.nej2008@gmail.com is None, should be None
# younes.nej2008@gmail.com is now None
# younes@wayne.edu is None, should be None
# younes@wayne.edu is now None
# ynejahi@localhost.localdomain is None, should be None
# ynejahi@localhost.localdomain is now None
# younesnejahi@gmail.com is None, should be None
# younesnejahi@gmail.com is now None
# go2432@wayne.edu is None, should be None
# go2432@wayne.edu is now None
# 39970712+GregorySchwing@users.noreply.github.com is None, should be None
# 39970712+GregorySchwing@users.noreply.github.com is now None
# 39970712+go2432@users.noreply.github.com is None, should be None
# 39970712+go2432@users.noreply.github.com is now None
# fj2314@wayne.edu is None, should be None
# fj2314@wayne.edu is now None
# zzzhe1990@gmail.com is None, should be None
# zzzhe1990@gmail.com is now None
# gschwing@uno.edu is None, should be None
# gschwing@uno.edu is now None
# Matt@Matt-PC is None, should be None
# Matt@Matt-PC is now None
# matt@cycronix.com is None, should be None
# matt@cycronix.com is now None
# jhayes@tscc-2-0.sdsc.edu is None, should be None
# jhayes@tscc-2-0.sdsc.edu is now None
# jhayes@sdsc.edu is None, should be None
# jhayes@sdsc.edu is now None
# luca.clementi@gmail.com is None, should be None
# luca.clementi@gmail.com is now None
# clem@lhc.(none) is None, should be None
# clem@lhc.(none) is now None
# lclementi@submit-1.batlab.org is None, should be None
# lclementi@submit-1.batlab.org is now None
# (no author)@6df8c730-e442-11dd-8fb1-9960f2a117f8 is None, should be None
# (no author)@6df8c730-e442-11dd-8fb1-9960f2a117f8 is now None
# mark@opencfd is None, should be None
# mark@opencfd is now None
# a.huebl@hzdr.de is None, should be None
# a.huebl@hzdr.de is now None
# jdayal3@vogue9.cc.gatech.edu is None, should be None
# jdayal3@vogue9.cc.gatech.edu is now None
# home@jai-dayals-macbook.local is None, should be None
# home@jai-dayals-macbook.local is now None
# jdayal3@vogue7.cc.gatech.edu is None, should be None
# jdayal3@vogue7.cc.gatech.edu is now None
# home@presentation01.in2change.local is None, should be None
# home@presentation01.in2change.local is now None
# jdayal3@vogue10.cc.gatech.edu is None, should be None
# jdayal3@vogue10.cc.gatech.edu is now None
# home@lawn-143-215-59-193.lawn.gatech.edu is None, should be None
# home@lawn-143-215-59-193.lawn.gatech.edu is now None
# dayalsoap@gmail.com is None, should be None
# dayalsoap@gmail.com is now None
# jdayal3@rohan8.cc.gatech.edu is None, should be None
# jdayal3@rohan8.cc.gatech.edu is now None
# jdayal3@rohan5.cc.gatech.edu is None, should be None
# jdayal3@rohan5.cc.gatech.edu is now None
# jdayal3@vogue8.cc.gatech.edu is None, should be None
# jdayal3@vogue8.cc.gatech.edu is now None
# jdayal3@rohan6.cc.gatech.edu is None, should be None
# jdayal3@rohan6.cc.gatech.edu is now None
# home@lawn-143-215-50-101.lawn.gatech.edu is None, should be None
# home@lawn-143-215-50-101.lawn.gatech.edu is now None
# jdayal3@rohan10.cc.gatech.edu is None, should be None
# jdayal3@rohan10.cc.gatech.edu is now None
# jdayal3@rohan7.cc.gatech.edu is None, should be None
# jdayal3@rohan7.cc.gatech.edu is now None
# jdayal3@sith-login1.ccs.ornl.gov is None, should be None
# jdayal3@sith-login1.ccs.ornl.gov is now None
# jyc@rhea-login7g.ccs.ornl.gov is None, should be None
# jyc@rhea-login7g.ccs.ornl.gov is now None
# choij@ornl.gov is None, should be None
# choij@ornl.gov is now None
# jyc@titan-ext7.ccs.ornl.gov is None, should be None
# jyc@titan-ext7.ccs.ornl.gov is now None
# jyc@titan-ext2.ccs.ornl.gov is None, should be None
# jyc@titan-ext2.ccs.ornl.gov is now None
# jyc@rhea-login3g.ccs.ornl.gov is None, should be None
# jyc@rhea-login3g.ccs.ornl.gov is now None
# jyc@titan-ext6.ccs.ornl.gov is None, should be None
# jyc@titan-ext6.ccs.ornl.gov is now None
# drew@crowdspots.com is None, should be None
# drew@crowdspots.com is now None
# junmin@hopper10.(none) is None, should be None
# junmin@hopper10.(none) is now None
# drewmbee@gmail.com is None, should be None
# drewmbee@gmail.com is now None
# axel.huebl@plasma.ninja is None, should be None
# axel.huebl@plasma.ninja is now None
# daboyuka@redacted is None, should be None
# daboyuka@redacted is now None
# home@android-ac6f560f9ca67c40.gateway.2wire.net is None, should be None
# home@android-ac6f560f9ca67c40.gateway.2wire.net is now None
# pnorbert@cetuslac1.fst.alcf.anl.gov is None, should be None
# pnorbert@cetuslac1.fst.alcf.anl.gov is now None
# pnorbert@ornl.gov is None, should be None
# pnorbert@ornl.gov is now None
# yyalli@gmail.com is None, should be None
# yyalli@gmail.com is now None
# jchoi446@maquis1.cc.gatech.edu is None, should be None
# jchoi446@maquis1.cc.gatech.edu is now None
# jchoi446@maquis7.cc.gatech.edu is None, should be None
# jchoi446@maquis7.cc.gatech.edu is now None
# yyalli@github.com is None, should be None
# yyalli@github.com is now None
# jychoi-hpc@users.noreply.github.com is None, should be None
# jychoi-hpc@users.noreply.github.com is now None
# pugmire@nostril is None, should be None
# pugmire@nostril is now None
# jya@titan-ext3.ccs.ornl.gov is None, should be None
# jya@titan-ext3.ccs.ornl.gov is now None
# jya@titan-ext5.ccs.ornl.gov is None, should be None
# jya@titan-ext5.ccs.ornl.gov is now None
# jya@titan-ext2.ccs.ornl.gov is None, should be None
# jya@titan-ext2.ccs.ornl.gov is now None
# jya@titan-ext8.ccs.ornl.gov is None, should be None
# jya@titan-ext8.ccs.ornl.gov is now None
# jya@titan-ext1.ccs.ornl.gov is None, should be None
# jya@titan-ext1.ccs.ornl.gov is now None
# jya@sith-login1.ccs.ornl.gov is None, should be None
# jya@sith-login1.ccs.ornl.gov is now None
# jya@lens-login4.ccs.ornl.gov is None, should be None
# jya@lens-login4.ccs.ornl.gov is now None
# jya@lens-login3.ccs.ornl.gov is None, should be None
# jya@lens-login3.ccs.ornl.gov is now None
# jya@titan-ext6.ccs.ornl.gov is None, should be None
# jya@titan-ext6.ccs.ornl.gov is now None
# jyc@titan-ext4.ccs.ornl.gov is None, should be None
# jyc@titan-ext4.ccs.ornl.gov is now None
# pnorbert@github.com is None, should be None
# pnorbert@github.com is now None
# jai@earlgrey.cc.gatech.edu is None, should be None
# jai@earlgrey.cc.gatech.edu is now None
# jai@lawn-143-215-205-196.lawn.gatech.edu is None, should be None
# jai@lawn-143-215-205-196.lawn.gatech.edu is now None
# kai.germaschewski@gmail.com is None, should be None
# kai.germaschewski@gmail.com is now None
# junmin@hopper04.(none) is None, should be None
# junmin@hopper04.(none) is now None
# jya@titan-ext4.ccs.ornl.gov is None, should be None
# jya@titan-ext4.ccs.ornl.gov is now None
# jeremy.logan@maine.edu is None, should be None
# jeremy.logan@maine.edu is now None
# habbasi@ornl.gov is None, should be None
# habbasi@ornl.gov is now None
# redviper@gmail.com is None, should be None
# redviper@gmail.com is now None
# jai@hadron.cc.gatech.edu is None, should be None
# jai@hadron.cc.gatech.edu is now None
# yyalli@users.noreply.github.com is None, should be None
# yyalli@users.noreply.github.com is now None
# qsun@sith-login1.ccs.ornl.gov is None, should be None
# qsun@sith-login1.ccs.ornl.gov is now None
# jlogan7@utk.edu is None, should be None
# jlogan7@utk.edu is now None
# kai.germaschewski@unh.edu is None, should be None
# kai.germaschewski@unh.edu is now None
# dpugmire@gmail.com is None, should be None
# dpugmire@gmail.com is now None
# tianyua@sith-login1.ccs.ornl.gov is None, should be None
# tianyua@sith-login1.ccs.ornl.gov is now None
# liuq@nid05417.(none) is None, should be None
# liuq@nid05417.(none) is now None
# qliu@miralac1.fst.alcf.anl.gov is None, should be None
# qliu@miralac1.fst.alcf.anl.gov is now None
# qliu@cetuslac1.fst.alcf.anl.gov is None, should be None
# qliu@cetuslac1.fst.alcf.anl.gov is now None
# qliu@sith-login1.ccs.ornl.gov is None, should be None
# qliu@sith-login1.ccs.ornl.gov is now None
# qliu@vestalac1.ftd.alcf.anl.gov is None, should be None
# qliu@vestalac1.ftd.alcf.anl.gov is now None
# liuq@ornl.gov is None, should be None
# liuq@ornl.gov is now None
# daboyuka@ncsu.edu is None, should be None
# daboyuka@ncsu.edu is now None
# YuanT@Yuans-MacBook-Air.local is None, should be None
# YuanT@Yuans-MacBook-Air.local is now None
# qsun@vestalac1.ftd.alcf.anl.gov is None, should be None
# qsun@vestalac1.ftd.alcf.anl.gov is now None
# habbasi@cc.gatech.edu is None, should be None
# habbasi@cc.gatech.edu is now None
# brian@8a072113-8704-0410-8d35-dd094bca7971 is None, should be None
# brian@8a072113-8704-0410-8d35-dd094bca7971 is now None
# julien.langou@ucdenver.edu is None, should be None
# julien.langou@ucdenver.edu is now None
# cmoha@users.noreply.github.com is None, should be None
# cmoha@users.noreply.github.com is now None
# pd.mes@cbs.dk is None, should be None
# pd.mes@cbs.dk is now None
# 55156186+pdalgd@users.noreply.github.com is None, should be None
# 55156186+pdalgd@users.noreply.github.com is now None
# mselhwala@hotmail.com is None, should be None
# mselhwala@hotmail.com is now None
# eugenechereshnev@gmail.com is None, should be None
# eugenechereshnev@gmail.com is now None
# echeresh@jflmkl025.jf.intel.com is None, should be None
# echeresh@jflmkl025.jf.intel.com is now None
# echeresh@mandrake.jf.intel.com is None, should be None
# echeresh@mandrake.jf.intel.com is now None
# ngoldbau@illinois.edu is None, should be ngoldbaum
# ngoldbau@illinois.edu is now ngoldbaum
# semeraro@login2.maverick.tacc.utexas.edu is None, should be None
# semeraro@login2.maverick.tacc.utexas.edu is now None
# semeraro@login4.stampede2.tacc.utexas.edu is None, should be None
# semeraro@login4.stampede2.tacc.utexas.edu is now None
# semeraro@c221-301.maverick.tacc.utexas.edu is None, should be None
# semeraro@c221-301.maverick.tacc.utexas.edu is now None
# semeraro@c221-603.maverick.tacc.utexas.edu is None, should be None
# semeraro@c221-603.maverick.tacc.utexas.edu is now None
# semeraro@login1.stampede2.tacc.utexas.edu is None, should be None
# semeraro@login1.stampede2.tacc.utexas.edu is now None
# semeraro@c221-803.maverick.tacc.utexas.edu is None, should be None
# semeraro@c221-803.maverick.tacc.utexas.edu is now None
# semeraro@c225-104.maverick.tacc.utexas.edu is None, should be None
# semeraro@c225-104.maverick.tacc.utexas.edu is now None
# semeraro@staff.maverick.tacc.utexas.edu is None, should be None
# semeraro@staff.maverick.tacc.utexas.edu is now None
# semeraro@login3.maverick.tacc.utexas.edu is None, should be None
# semeraro@login3.maverick.tacc.utexas.edu is now None
# semeraro@login1.maverick.tacc.utexas.edu is None, should be None
# semeraro@login1.maverick.tacc.utexas.edu is now None
# semeraro@c221-504.maverick.tacc.utexas.edu is None, should be None
# semeraro@c221-504.maverick.tacc.utexas.edu is now None
# semeraro@login2.stampede2.tacc.utexas.edu is None, should be None
# semeraro@login2.stampede2.tacc.utexas.edu is now None
# semeraro@login3.stampede2.tacc.utexas.edu is None, should be None
# semeraro@login3.stampede2.tacc.utexas.edu is now None
# hyungman@utexas.edu is None, should be None
# hyungman@utexas.edu is now None
# barbosa.garcia@gmail.com is None, should be None
# barbosa.garcia@gmail.com is now None
# jbarbosa@tacc.utexas.edu is None, should be None
# jbarbosa@tacc.utexas.edu is now None
# jbarbosa@staff.stampede2.tacc.utexas.edu not found
# jbarbosa@cs.utexas.edu is None, should be None
# jbarbosa@cs.utexas.edu is now None
# carson@tacc.utexas.edu is None, should be None
# carson@tacc.utexas.edu is now None
# carson@login1.stampede.tacc.utexas.edu is None, should be None
# carson@login1.stampede.tacc.utexas.edu is now None
# sam.wenke@inin.com is None, should be None
# sam.wenke@inin.com is now None
# wenkesj@users.noreply.github.com is None, should be None
# wenkesj@users.noreply.github.com is now None
# sam.wenke@Sams-MacBook-Pro.local is None, should be None
# sam.wenke@Sams-MacBook-Pro.local is now None
# jbarbosa@localhost.localdomain is None, should be joaobb
# jbarbosa@localhost.localdomain is now joaobb
# srinathv@paratools.com not found
# ashish.gehani@sri.com is None, should be None
# ashish.gehani@sri.com is now None
# ashish.gehani@gmail.com is None, should be None
# ashish.gehani@gmail.com is now None
# 38260180+shoaibCS@users.noreply.github.com is None, should be None
# 38260180+shoaibCS@users.noreply.github.com is now None
# gehani@shaman.csl.sri.com is None, should be None
# gehani@shaman.csl.sri.com is now None
# 19100080@lums.edu.pk is None, should be None
# 19100080@lums.edu.pk is now None
# umesh.timalsina@vanderbilt.edu is None, should be umesh-timalsina
# umesh.timalsina@vanderbilt.edu is now umesh-timalsina
# justin.b.gilmer@gmail.com is None, should be None
# justin.b.gilmer@gmail.com is now None

# %%
id_dict['jkew@vmware.com']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-0555d79c40d7> in <module>
# ----> 1 id_dict['jkew@vmware.com']
#
# KeyError: 'jkew@vmware.com'

# %%
    test_df = pd.DataFrame()
    test_df_query = f"""
            SELECT * from commits
            WHERE cmt_author_email = 'jkew@vmware.com'
            """
    test_df = pd.read_sql_query(test_df_query, con=engine)
    test_df
# Out:
# Empty DataFrame
# Columns: [cmt_id, repo_id, cmt_commit_hash, cmt_author_name, cmt_author_raw_email, cmt_author_email, cmt_author_date, cmt_author_affiliation, cmt_committer_name, cmt_committer_raw_email, cmt_committer_email, cmt_committer_date, cmt_committer_affiliation, cmt_added, cmt_removed, cmt_whitespace, cmt_filename, cmt_date_attempted, cmt_ght_author_id, cmt_ght_committer_id, cmt_ght_committed_at, tool_source, tool_version, data_source, data_collection_date, cmt_author_timestamp, cmt_committer_timestamp]
# Index: []
#
# [0 rows x 27 columns]

# %%
    test_df = pd.DataFrame()
    test_df_query = f"""
            SELECT * from contributors
            WHERE cntrb_email = 'jkew@vmware.com'
            """
    test_df = pd.read_sql_query(test_df_query, con=engine)
    test_df
# Out:
# Empty DataFrame
# Columns: [cntrb_id, cntrb_login, cntrb_email, cntrb_company, cntrb_created_at, cntrb_type, cntrb_fake, cntrb_deleted, cntrb_long, cntrb_lat, cntrb_country_code, cntrb_state, cntrb_city, cntrb_location, cntrb_canonical, gh_user_id, gh_login, gh_url, gh_html_url, gh_node_id, gh_avatar_url, gh_gravatar_id, gh_followers_url, gh_following_url, gh_gists_url, gh_starred_url, gh_subscriptions_url, gh_organizations_url, gh_repos_url, gh_events_url, gh_received_events_url, gh_type, gh_site_admin, tool_source, tool_version, data_source, data_collection_date, cntrb_full_name, cntrb_last_used]
# Index: []
#
# [0 rows x 39 columns]

# %%
# test to get gh login - not sure why there are so many fewer rows returned?
all_commits = pd.DataFrame()
all_commits_query = f"""
        SELECT DISTINCT(commits.cmt_commit_hash), repo.repo_id, repo.repo_name, repo.repo_path, contributors.cntrb_login, 
            commits.cmt_author_email, commits.cmt_author_timestamp from repo, commits, contributors
        WHERE 
            repo.repo_id = commits.repo_id
            AND contributors.cntrb_canonical = commits.cmt_author_email
        GROUP BY repo.repo_id, commits.cmt_commit_hash, commits.cmt_author_email, commits.cmt_author_timestamp, contributors.cntrb_login
        ORDER BY repo.repo_id;
        """
all_commits = pd.read_sql_query(all_commits_query, con=engine)
all_commits
# Out:
#                                  cmt_commit_hash  repo_id    repo_name  \
# 0       003e7eb431b94df2fcb76b19eb80216f9ee98ae0    25430        foyer
# 1       0044f56b49ef33df95b8a6fdb4352ef02621f2e4    25430        foyer
# 2       00a64c696a260718450d8234bf3b7ee250724583    25430        foyer
# 3       00beaebdf175fd9462f70a304a55f05d5b9c525e    25430        foyer
# 4       00cbc229fb5c3c437f80afd5dbcd6e8b2e042c3f    25430        foyer
# ...                                          ...      ...          ...
# 362693  ff47aeb600949e47d74c2c77481660361ee690e1    25521  SimVascular
# 362694  ff4bc6b11b39968e2f460ed67f72d71e842468cf    25521  SimVascular
# 362695  ff71ca2d7c5112564d306c2b5b04697a87f9c3ac    25521  SimVascular
# 362696  ff8066a6654f81a7b2e882300bc3968b000c8ced    25521  SimVascular
# 362697  ff9f87288531c9d5eed2845c466a0fb7cf88d670    25521  SimVascular
#
#                       repo_path cntrb_login                cmt_author_email  \
# 0        github.com/mosdef-hub/        None  christoph.klein@vanderbilt.edu
# 1        github.com/mosdef-hub/        None  christoph.klein@vanderbilt.edu
# 2        github.com/mosdef-hub/        None  christoph.klein@vanderbilt.edu
# 3        github.com/mosdef-hub/        None  christoph.klein@vanderbilt.edu
# 4        github.com/mosdef-hub/        None            mattwthomp@gmail.com
# ...                         ...         ...                             ...
# 362693  github.com/SimVascular/        None              h1lan@eng.ucsd.edu
# 362694  github.com/SimVascular/        None              h1lan@eng.ucsd.edu
# 362695  github.com/SimVascular/        None              h1lan@eng.ucsd.edu
# 362696  github.com/SimVascular/        None  osmsc@users.noreply.github.com
# 362697  github.com/SimVascular/        None  osmsc@users.noreply.github.com
#
#              cmt_author_timestamp
# 0       2016-01-14 06:56:34+01:00
# 1       2017-02-09 19:05:48+01:00
# 2       2017-02-13 18:59:39+01:00
# 3       2017-03-09 17:39:36+01:00
# 4       2019-11-25 20:13:15+01:00
# ...                           ...
# 362693  2017-07-03 00:07:04+02:00
# 362694  2017-07-28 00:30:35+02:00
# 362695  2017-06-07 01:28:04+02:00
# 362696  2018-11-17 20:57:36+01:00
# 362697  2018-01-13 09:31:16+01:00
#
# [362698 rows x 7 columns]
