# %%
import psycopg2
import pandas as pd 
# from sqlalchemy.types import Integer, Text, String, DateTime
import sqlalchemy as s
import matplotlib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

with open("config.json") as config_file:
    config = json.load(config_file)

database_connection_string = 'postgres+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = s.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %%
repo_list = pd.DataFrame()
repo_list_query = f"""
SELECT repo_id, repo_name, repo_path from repo;
    """
repo_list = pd.read_sql_query(repo_list_query, con=engine)
print(repo_list)
# Out:
#     repo_id            repo_name                                 repo_path
# 0     25506        rphash-golang                      github.com/wilseypa/
# 1     25511               aspect                   github.com/geodynamics/
# 2     25454                 psi4                          github.com/psi4/
# 3     25521          SimVascular                   github.com/SimVascular/
# 4     25439         purdue-fastr                          github.com/allr/
# ..      ...                  ...                                       ...
# 87    25503                OSHUN  github.com/UCLA-Plasma-Simulation-Group/
# 88    25504  QuickPIC-OpenSource  github.com/UCLA-Plasma-Simulation-Group/
# 89    25453              panache                 github.com/CrawfordGroup/
# 90    25474                draft                     github.com/cplusplus/
# 91    25485                Block                       github.com/sanshar/
#
# [92 rows x 3 columns]

# %%
repo_id = 25445
repo_list = pd.DataFrame()
repo_list_query = f"""
SELECT repo_groups.rg_name from repo_groups, repo
    WHERE 
    repo.repo_id = {repo_id}
    AND repo.repo_group_id = repo_groups.repo_group_id;
    """
repo_list = pd.read_sql_query(repo_list_query, con=engine)
print(repo_list.rg_name[0])
print(repo_id)
# Out:
# Howison Repos
# 25445

# %%
i = 0
for index, repo in repo_list.iterrows():
    repo_id = repo['repo_id']
    print(repo_id)
    
    repo_list_commits_query = f"""
            SELECT DISTINCT COUNT(cmt_commit_hash) from commits
            WHERE 
                repo_id = {repo_id};
            """
    repo_list_commits = pd.read_sql_query(repo_list_commits_query, con=engine)
    print(repo_list_commits)
    
    i+=1
    if i == 10:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-51dce46454b4> in <module>
#       1 i = 0
#       2 for index, repo in repo_list.iterrows():
# ----> 3     repo_id = repo['repo_id']
#       4     print(repo_id)
#       5
#
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4417                     raise InvalidIndexError(key)
#    4418                 else:
# -> 4419                     raise e1
#    4420             except Exception:
#    4421                 raise e1
#
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'repo_id'

# %%
#from datetime import date
import datetime 

current = datetime.date.today()
today = "'" + str(current) + "'"
#print(today)

first_current = current.replace(day=1)
last_month = first_current - datetime.timedelta(days=1)
end_date = "'" + str(last_month) + "'"
#print(end_date)

start = last_month - datetime.timedelta(days=365) #### 6 MONTHS
start_date = "'" + str(start) + "'"

print(start_date, end_date)
# Out:
# '2020-02-01' '2021-01-31'

# %%
    repo_list_commits = pd.DataFrame()
    repo_list_commits_query = f"""
            SELECT repo.repo_id, repo.repo_name, repo.repo_path, repo.forked_from, COUNT(commits.cmt_id) from repo, commits
            WHERE 
                repo.repo_id = commits.repo_id
                AND commits.cmt_author_timestamp >= {start_date}
                AND commits.cmt_author_timestamp <= {end_date}
            GROUP BY repo.repo_id
            ORDER BY COUNT(commits.cmt_id);
            """
    repo_list_commits = pd.read_sql_query(repo_list_commits_query, con=engine)
    print(repo_list_commits)
# Out:
#     repo_id    repo_name                               repo_path  \
# 0     25464       archer                     github.com/PRUNERS/
# 1     25460     archer-1                     github.com/PRUNERS/
# 2     25459     libflame                       github.com/flame/
# 3     25486        ADIOS                   github.com/ornladios/
# 4     25481        UCVMC                    github.com/SCECcode/
# 5     25492      tephra2  github.com/geoscience-community-codes/
# 6     25493      titan2d                     github.com/TITAN2D/
# 7     25462         FLiT                     github.com/PRUNERS/
# 8     25518      foyer-1                  github.com/mosdef-hub/
# 9     25430        foyer                  github.com/mosdef-hub/
# 10    25516       uproot                  github.com/scikit-hep/
# 11    25431       mbuild                  github.com/mosdef-hub/
# 12    25494       lapack            github.com/Reference-LAPACK/
# 13    25521  SimVascular                 github.com/SimVascular/
# 14    25469       scifio                      github.com/scifio/
# 15    25510        OCCAM                     github.com/SRI-CSL/
# 16    25451      landlab                     github.com/landlab/
# 17    25468      cctools   github.com/cooperative-computing-lab/
# 18    25466         GOMC                    github.com/GOMC-WSU/
# 19    25437       silver                    github.com/melt-umn/
# 20    25436     silver-1                    github.com/melt-umn/
# 21    25497         ompi                    github.com/open-mpi/
# 22    25438        fastr                      github.com/oracle/
# 23    25447         quda                     github.com/lattice/
# 24    25520           yt                  github.com/yt-project/
# 25    25448      boinc-1                       github.com/BOINC/
# 26    25484        boinc                       github.com/BOINC/
# 27    25454         psi4                        github.com/psi4/
# 28    25483      pegasus                 github.com/pegasus-isi/
# 29    25511       aspect                 github.com/geodynamics/
# 30    25450         sage                    github.com/sagemath/
# 31    25457       dealii                      github.com/dealii/
# 32    25458     Trilinos                    github.com/trilinos/
#
#              forked_from  count
# 0                   None      1
# 1   Parent not available      1
# 2   Parent not available      3
# 3   Parent not available     11
# 4   Parent not available     24
# 5   Parent not available     29
# 6   Parent not available     38
# 7   Parent not available    132
# 8                   None    142
# 9   Parent not available    142
# 10  Parent not available    201
# 11  Parent not available    266
# 12  Parent not available    429
# 13  Parent not available    713
# 14  Parent not available    769
# 15   ashish-gehani/OCCAM    970
# 16  Parent not available   1039
# 17  Parent not available   1611
# 18  Parent not available   2038
# 19                  None   3118
# 20  Parent not available   3118
# 21  Parent not available   3147
# 22  Parent not available   3885
# 23  Parent not available   4563
# 24  Parent not available   4878
# 25  Parent not available   5039
# 26                  None   5039
# 27  Parent not available   7017
# 28  Parent not available   7090
# 29  Parent not available   7974
# 30  Parent not available  17745
# 31  Parent not available  18951
# 32  Parent not available  37539

# %%
    repo_list_commits = pd.DataFrame()
    repo_list_commits_query = f"""
            SELECT count(distinct commits.cmt_commit_hash), repo.repo_id, repo.repo_name, repo.repo_path from repo, commits
            WHERE 
                repo.repo_id = commits.repo_id
                AND commits.cmt_author_timestamp >= {start_date}
                AND commits.cmt_author_timestamp <= {end_date}
            GROUP BY repo.repo_id
            ORDER BY count(distinct commits.cmt_commit_hash);
            """
    repo_list_commits = pd.read_sql_query(repo_list_commits_query, con=engine)
    repo_list_commits
    #repo_list_commits.loc[repo_list_commits.repo_id == 28031]
    #df.loc[df.a == 3
    #.loc["California","2013"]
# Out:
#     count  repo_id    repo_name                               repo_path
# 0       1    25460     archer-1                     github.com/PRUNERS/
# 1       1    25464       archer                     github.com/PRUNERS/
# 2       2    25459     libflame                       github.com/flame/
# 3       6    25486        ADIOS                   github.com/ornladios/
# 4      14    25481        UCVMC                    github.com/SCECcode/
# 5      20    25493      titan2d                     github.com/TITAN2D/
# 6      26    25492      tephra2  github.com/geoscience-community-codes/
# 7      54    25469       scifio                      github.com/scifio/
# 8      58    25462         FLiT                     github.com/PRUNERS/
# 9      62    25518      foyer-1                  github.com/mosdef-hub/
# 10     62    25430        foyer                  github.com/mosdef-hub/
# 11     75    25516       uproot                  github.com/scikit-hep/
# 12    116    25494       lapack            github.com/Reference-LAPACK/
# 13    130    25431       mbuild                  github.com/mosdef-hub/
# 14    160    25521  SimVascular                 github.com/SimVascular/
# 15    177    25451      landlab                     github.com/landlab/
# 16    234    25510        OCCAM                     github.com/SRI-CSL/
# 17    590    25468      cctools   github.com/cooperative-computing-lab/
# 18    750    25437       silver                    github.com/melt-umn/
# 19    750    25436     silver-1                    github.com/melt-umn/
# 20    790    25466         GOMC                    github.com/GOMC-WSU/
# 21    806    25438        fastr                      github.com/oracle/
# 22    891    25454         psi4                        github.com/psi4/
# 23    902    25497         ompi                    github.com/open-mpi/
# 24   1223    25447         quda                     github.com/lattice/
# 25   1407    25448      boinc-1                       github.com/BOINC/
# 26   1407    25484        boinc                       github.com/BOINC/
# 27   1430    25511       aspect                 github.com/geodynamics/
# 28   1837    25520           yt                  github.com/yt-project/
# 29   2280    25483      pegasus                 github.com/pegasus-isi/
# 30   4102    25458     Trilinos                    github.com/trilinos/
# 31   4316    25457       dealii                      github.com/dealii/
# 32   7819    25450         sage                    github.com/sagemath/

# %%
top = repo_list_commits.loc[repo_list_commits['count'] > 2400]

# %%
len(top.repo_id)
# Out:
# 3

# %%
top
# Out:
#     count  repo_id repo_name             repo_path
# 30   4102    25458  Trilinos  github.com/trilinos/
# 31   4316    25457    dealii    github.com/dealii/
# 32   7819    25450      sage  github.com/sagemath/

# %%
    for index, repo in top.iterrows():
        print(repo['repo_id'], repo['repo_name'])
# Out:
# 25458 Trilinos
# 25457 dealii
# 25450 sage

# %%
    commit_exp = pd.DataFrame()
    commit_exp_query = f"""
            SELECT DISTINCT cmt_commit_hash, commits.cmt_author_timestamp from commits
            WHERE 
                commits.repo_id = 26983
                AND commits.cmt_author_timestamp >= '2019-07-01'
                AND commits.cmt_author_timestamp <= '2019-08-01'
            ORDER BY commits.cmt_author_timestamp;
            """
    commit_exp = pd.read_sql_query(commit_exp_query, con=engine)
    print(commit_exp)
# Out:
# Empty DataFrame
# Columns: [cmt_commit_hash, cmt_author_timestamp]
# Index: []

# %%
    commit_exp = pd.DataFrame()
    commit_exp_query = f"""
            SELECT updated_at, repo_id from repo
            ORDER BY updated_at
            """
    commit_exp = pd.read_sql_query(commit_exp_query, con=engine)
    print(commit_exp)
# Out:
#    updated_at  repo_id
# 0        None    25506
# 1        None    25511
# 2        None    25454
# 3        None    25521
# 4        None    25439
# ..        ...      ...
# 87       None    25503
# 88       None    25504
# 89       None    25453
# 90       None    25474
# 91       None    25485
#
# [92 rows x 2 columns]

# %%
    all_commits = pd.DataFrame()
    all_commits_query = f"""
            SELECT DISTINCT(commits.cmt_commit_hash), repo.repo_id, repo.repo_name, repo.repo_path, 
                commits.cmt_author_email, commits.cmt_author_timestamp from repo, commits
            WHERE 
                repo.repo_id = commits.repo_id
            GROUP BY repo.repo_id, commits.cmt_commit_hash, commits.cmt_author_email, commits.cmt_author_timestamp
            ORDER BY repo.repo_id;
            """
    all_commits = pd.read_sql_query(all_commits_query, con=engine)
    all_commits
# Out:
#                                  cmt_commit_hash  repo_id    repo_name  \
# 0       001dd26e0aa4662b298c0a44f281a016ff416b99    25430        foyer
# 1       003e7eb431b94df2fcb76b19eb80216f9ee98ae0    25430        foyer
# 2       0044f56b49ef33df95b8a6fdb4352ef02621f2e4    25430        foyer
# 3       00a64c696a260718450d8234bf3b7ee250724583    25430        foyer
# 4       00beaebdf175fd9462f70a304a55f05d5b9c525e    25430        foyer
# ...                                          ...      ...          ...
# 498110  ff71e8b69a92c3af89cd2557f950ee354644e608    25521  SimVascular
# 498111  ff8066a6654f81a7b2e882300bc3968b000c8ced    25521  SimVascular
# 498112  ff9f87288531c9d5eed2845c466a0fb7cf88d670    25521  SimVascular
# 498113  ffcb2108af1be253a493429212b0a7572b03f992    25521  SimVascular
# 498114  ffd6f5a264a182cd6f5e4c772f4d13523630066a    25521  SimVascular
#
#                       repo_path                 cmt_author_email  \
# 0        github.com/mosdef-hub/  raymat@master.cl.vanderbilt.edu
# 1        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# 2        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# 3        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# 4        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# ...                         ...                              ...
# 498110  github.com/SimVascular/              gmaher2@hotmail.com
# 498111  github.com/SimVascular/   osmsc@users.noreply.github.com
# 498112  github.com/SimVascular/   osmsc@users.noreply.github.com
# 498113  github.com/SimVascular/   adamupdegrove@Adams-iMac.local
# 498114  github.com/SimVascular/   adamupdegrove@Adams-iMac.local
#
#              cmt_author_timestamp
# 0       2019-06-12 18:50:38+02:00
# 1       2016-01-14 06:56:34+01:00
# 2       2017-02-09 19:05:48+01:00
# 3       2017-02-13 18:59:39+01:00
# 4       2017-03-09 17:39:36+01:00
# ...                           ...
# 498110  2019-04-25 01:34:37+02:00
# 498111  2018-11-17 20:57:36+01:00
# 498112  2018-01-13 09:31:16+01:00
# 498113  2017-09-20 18:20:32+02:00
# 498114  2017-07-13 17:55:34+02:00
#
# [498115 rows x 6 columns]

# %%
#all_commits.loc[all_commits['repo_id']]
all_commits['cmt_author_timestamp'].min()
all_commits['cmt_author_timestamp'].max()
#all_commits = all_commits.reset_index().groupby([all_commits.cmt_author_timestamp]).max().set_index('index')
all_commits.loc[all_commits.groupby('repo_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c230fdae2da3> in <module>
#       3 all_commits['cmt_author_timestamp'].max()
#       4 #all_commits = all_commits.reset_index().groupby([all_commits.cmt_author_timestamp]).max().set_index('index')
# ----> 5 all_commits.loc[all_commits.groupby('repo_id').cmt_author_timestamp.idxmax()].sort_values('cmt_author_timestamp')
#
# ~/github/virtualenvs/acr/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#     654             if self.obj.ndim == 1:
#     655                 # this can be called recursively, so need to raise ValueError
# --> 656                 raise ValueError
#     657
#     658             # GH#3688 try to operate item-by-item
#
# ValueError:

# %%
all_commits
# Out:
#                                  cmt_commit_hash  repo_id    repo_name  \
# 0       001dd26e0aa4662b298c0a44f281a016ff416b99    25430        foyer
# 1       003e7eb431b94df2fcb76b19eb80216f9ee98ae0    25430        foyer
# 2       0044f56b49ef33df95b8a6fdb4352ef02621f2e4    25430        foyer
# 3       00a64c696a260718450d8234bf3b7ee250724583    25430        foyer
# 4       00beaebdf175fd9462f70a304a55f05d5b9c525e    25430        foyer
# ...                                          ...      ...          ...
# 498110  ff71e8b69a92c3af89cd2557f950ee354644e608    25521  SimVascular
# 498111  ff8066a6654f81a7b2e882300bc3968b000c8ced    25521  SimVascular
# 498112  ff9f87288531c9d5eed2845c466a0fb7cf88d670    25521  SimVascular
# 498113  ffcb2108af1be253a493429212b0a7572b03f992    25521  SimVascular
# 498114  ffd6f5a264a182cd6f5e4c772f4d13523630066a    25521  SimVascular
#
#                       repo_path                 cmt_author_email  \
# 0        github.com/mosdef-hub/  raymat@master.cl.vanderbilt.edu
# 1        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# 2        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# 3        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# 4        github.com/mosdef-hub/   christoph.klein@vanderbilt.edu
# ...                         ...                              ...
# 498110  github.com/SimVascular/              gmaher2@hotmail.com
# 498111  github.com/SimVascular/   osmsc@users.noreply.github.com
# 498112  github.com/SimVascular/   osmsc@users.noreply.github.com
# 498113  github.com/SimVascular/   adamupdegrove@Adams-iMac.local
# 498114  github.com/SimVascular/   adamupdegrove@Adams-iMac.local
#
#              cmt_author_timestamp
# 0       2019-06-12 18:50:38+02:00
# 1       2016-01-14 06:56:34+01:00
# 2       2017-02-09 19:05:48+01:00
# 3       2017-02-13 18:59:39+01:00
# 4       2017-03-09 17:39:36+01:00
# ...                           ...
# 498110  2019-04-25 01:34:37+02:00
# 498111  2018-11-17 20:57:36+01:00
# 498112  2018-01-13 09:31:16+01:00
# 498113  2017-09-20 18:20:32+02:00
# 498114  2017-07-13 17:55:34+02:00
#
# [498115 rows x 6 columns]

# %%
all_commits.loc[all_commits['repo_id'] == 25435].cmt_author_email.value_counts()
# Out:
# Series([], Name: cmt_author_email, dtype: int64)

# %%
repo_list_commits.loc[repo_list_commits['count'] > 2400]
# Out:
#     count  repo_id repo_name             repo_path
# 30   4102    25458  Trilinos  github.com/trilinos/
# 31   4316    25457    dealii    github.com/dealii/
# 32   7819    25450      sage  github.com/sagemath/
